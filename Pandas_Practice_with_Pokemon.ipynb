# %% [markdown]
# # Pandas Operation
# ---

# %% [markdown]
# ## Importing Required Modules
# 1. importing numpy for mathematical operation on arrays and dataframe.
# 2. importing pandas for reading data and data manipualtion.

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Reading dadaset

# %%
df=pd.read_csv('/content/pokemon.csv')

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df.shape
# Out:
# (800, 12)

# %% [markdown]
# ## To read 5 rows from starting

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %% [markdown]
# ## To read last 5 rows

# %%
df.tail()
# Out:
#        #                 Name   Type 1 Type 2  HP  Attack  Defense  Sp. Atk  \
# 795  719              Diancie     Rock  Fairy  50     100      150      100
# 796  719  DiancieMega Diancie     Rock  Fairy  50     160      110      160
# 797  720  HoopaHoopa Confined  Psychic  Ghost  80     110       60      150
# 798  720   HoopaHoopa Unbound  Psychic   Dark  80     160       60      170
# 799  721            Volcanion     Fire  Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 795      150     50           6       True
# 796      110    110           6       True
# 797      130     70           6       True
# 798      130     80           6       True
# 799       90     70           6       True

# %% [markdown]
# ### Short Description abot the Dataset
# - Pokedex entry number of the Pokemon
#
# pokedex is an  catalog that provide information regarding the various species of Pokémon featured in the Pokémon video game, anime and manga series.)
# - Name = name of the Pokemon
# - Type 1 = each Pokemon has a type, this determines weakness/resistance to attacks [referred to as the primary type]
# - Type 2 = some Pokemon are dual type and have 2 [referred to as the secondary type]
# - Total sum of all stats that come after this, a general guide to how strong a Pokemon is
# - HP = hit points, or health, defines how much damage a Pokemon can withstand before fainting
# - Attack =  the base modifier for normal attacks
# - Defense = the base damage resistance against normal attacks
# - Sp. Atk = special attack, the base modifier for special attacks
# - Sp. Def = the base damage resistance against special attacks
# - Speed = determines which Pokemon attacks first each round
# - Generation = refers to which grouping/game series the Pokemon was released in
# - Legendary = a boolean that identifies whether the Pokemon is legendary

# %% [markdown]
# ## To check the rows and columns in a data

# %%
df.shape
# Out:
# (800, 12)

# %% [markdown]
# ## To see all the columns in a data

# %%
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %% [markdown]
# ## To check the datatypes of a column

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      359 non-null    object
#  4   HP          800 non-null    int64
#  5   Attack      800 non-null    int64
#  6   Defense     800 non-null    int64
#  7   Sp. Atk     800 non-null    int64
#  8   Sp. Def     800 non-null    int64
#  9   Speed       800 non-null    int64
#  10  Generation  800 non-null    int64
#  11  Legendary   800 non-null    bool
# dtypes: bool(1), int64(8), object(3)
# memory usage: 69.7+ KB

# %% [markdown]
# ## To see the stats of the data

# %%
df.describe() # numeric cols
# Out:
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.750000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.250000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# ...

# %%
df.describe(include='object') # non numeric
# Out:
#                        Name Type 1  Type 2
# count                   800    800     359
# unique                  800     18      18
# top     PumpkabooSuper Size  Water  Flying
# freq                      1    112      81

# %% [markdown]
# ## To check the missing values in data

# %%
df.isnull().sum()
# Out:
# #               0
# Name            0
# Type 1          0
# Type 2        441
# HP              0
# Attack          0
# Defense         0
# Sp. Atk         0
# Sp. Def         0
# Speed           0
# Generation      0
# Legendary       0
# dtype: int64

# %%
df.isnull().sum()/df.shape[0]*100
# Out:
# #              0.000
# Name           0.000
# Type 1         0.000
# Type 2        55.125
# HP             0.000
# Attack         0.000
# Defense        0.000
# Sp. Atk        0.000
# Sp. Def        0.000
# Speed          0.000
# Generation     0.000
# Legendary      0.000
# dtype: float64

# %% [markdown]
# ## To drop the any column in a data

# %%
df.drop(columns=['Type 2', '#'],inplace=True)

# %%
df
# Out:
#                       Name   Type 1  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0                Bulbasaur    Grass  45      49       49       65       65
# 1                  Ivysaur    Grass  60      62       63       80       80
# 2                 Venusaur    Grass  80      82       83      100      100
# 3    VenusaurMega Venusaur    Grass  80     100      123      122      120
# 4               Charmander     Fire  39      52       43       60       50
# ..                     ...      ...  ..     ...      ...      ...      ...
# 795                Diancie     Rock  50     100      150      100      150
# 796    DiancieMega Diancie     Rock  50     160      110      160      110
# 797    HoopaHoopa Confined  Psychic  80     110       60      150      130
# 798     HoopaHoopa Unbound  Psychic  80     160       60      170      130
# 799              Volcanion     Fire  80     110      120      130       90
#
#      Speed  Generation  Legendary
# ...

# %%
df
# Out:
#                       Name   Type 1  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0                Bulbasaur    Grass  45      49       49       65       65
# 1                  Ivysaur    Grass  60      62       63       80       80
# 2                 Venusaur    Grass  80      82       83      100      100
# 3    VenusaurMega Venusaur    Grass  80     100      123      122      120
# 4               Charmander     Fire  39      52       43       60       50
# ..                     ...      ...  ..     ...      ...      ...      ...
# 795                Diancie     Rock  50     100      150      100      150
# 796    DiancieMega Diancie     Rock  50     160      110      160      110
# 797    HoopaHoopa Confined  Psychic  80     110       60      150      130
# 798     HoopaHoopa Unbound  Psychic  80     160       60      170      130
# 799              Volcanion     Fire  80     110      120      130       90
#
#      Speed  Generation  Legendary
# ...

# %% [markdown]
# ## To read each column

# %%
df
# Out:
#                       Name   Type 1  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0                Bulbasaur    Grass  45      49       49       65       65
# 1                  Ivysaur    Grass  60      62       63       80       80
# 2                 Venusaur    Grass  80      82       83      100      100
# 3    VenusaurMega Venusaur    Grass  80     100      123      122      120
# 4               Charmander     Fire  39      52       43       60       50
# ..                     ...      ...  ..     ...      ...      ...      ...
# 795                Diancie     Rock  50     100      150      100      150
# 796    DiancieMega Diancie     Rock  50     160      110      160      110
# 797    HoopaHoopa Confined  Psychic  80     110       60      150      130
# 798     HoopaHoopa Unbound  Psychic  80     160       60      170      130
# 799              Volcanion     Fire  80     110      120      130       90
#
#      Speed  Generation  Legendary
# ...

# %%
df.shape
# Out:
# (800, 10)

# %%
df['Name']
# Out:
# 0                  Bulbasaur
# 1                    Ivysaur
# 2                   Venusaur
# 3      VenusaurMega Venusaur
# 4                 Charmander
#                ...
# 795                  Diancie
# 796      DiancieMega Diancie
# 797      HoopaHoopa Confined
# 798       HoopaHoopa Unbound
# 799                Volcanion
# Name: Name, Length: 800, dtype: object

# %%
for i in df['Name']:
    print(i)
# Out:
# Bulbasaur
# Ivysaur
# Venusaur
# VenusaurMega Venusaur
# Charmander
# Charmeleon
# Charizard
# CharizardMega Charizard X
# CharizardMega Charizard Y
# Squirtle
# Wartortle
# Blastoise
# BlastoiseMega Blastoise
# Caterpie
# Metapod
# Butterfree
# Weedle
# Kakuna
# Beedrill
# BeedrillMega Beedrill
# Pidgey
# Pidgeotto
# Pidgeot
# PidgeotMega Pidgeot
# Rattata
# Raticate
# Spearow
# Fearow
# Ekans
# Arbok
# Pikachu
# Raichu
# Sandshrew
# Sandslash
# Nidoran (Female)
# Nidorina
# Nidoqueen
# Nidoran (Male)
# Nidorino
# Nidoking
# Clefairy
# Clefable
# Vulpix
# Ninetales
# Jigglypuff
# Wigglytuff
# Zubat
# Golbat
# Oddish
# Gloom
# Vileplume
# Paras
# Parasect
# Venonat
# Venomoth
# Diglett
# Dugtrio
# Meowth
# Persian
# Psyduck
# Golduck
# Mankey
# Primeape
# Growlithe
# Arcanine
# Poliwag
# Poliwhirl
# Poliwrath
# Abra
# Kadabra
# Alakazam
# AlakazamMega Alakazam
# Machop
# Machoke
# Machamp
# Bellsprout
# Weepinbell
# Victreebel
# Tentacool
# Tentacruel
# Geodude
# Graveler
# Golem
# ...

# %% [markdown]
# ## To read multiple columns

# %%
df[['Name','Type 1','HP']]
# Out:
#                       Name   Type 1  HP
# 0                Bulbasaur    Grass  45
# 1                  Ivysaur    Grass  60
# 2                 Venusaur    Grass  80
# 3    VenusaurMega Venusaur    Grass  80
# 4               Charmander     Fire  39
# ..                     ...      ...  ..
# 795                Diancie     Rock  50
# 796    DiancieMega Diancie     Rock  50
# 797    HoopaHoopa Confined  Psychic  80
# 798     HoopaHoopa Unbound  Psychic  80
# 799              Volcanion     Fire  80
#
# [800 rows x 3 columns]

# %% [markdown]
# ## To read multiple columns with a certain rows

# %%
df[['Name','Type 1']][200:211]
# Out:
#           Name  Type 1
# 200  Sudowoodo    Rock
# 201   Politoed   Water
# 202     Hoppip   Grass
# 203   Skiploom   Grass
# 204   Jumpluff   Grass
# 205      Aipom  Normal
# 206    Sunkern   Grass
# 207   Sunflora   Grass
# 208      Yanma     Bug
# 209     Wooper   Water
# 210   Quagsire   Water

# %%
df.iloc[200:211,0:2]
# Out:
#           Name  Type 1
# 200  Sudowoodo    Rock
# 201   Politoed   Water
# 202     Hoppip   Grass
# 203   Skiploom   Grass
# 204   Jumpluff   Grass
# 205      Aipom  Normal
# 206    Sunkern   Grass
# 207   Sunflora   Grass
# 208      Yanma     Bug
# 209     Wooper   Water
# 210   Quagsire   Water

# %% [markdown]
# ## To read each row
#
# > Add blockquote

# %%
df.iloc[9]
# Out:
# Name          Squirtle
# Type 1           Water
# HP                  44
# Attack              48
# Defense             65
# Sp. Atk             50
# Sp. Def             64
# Speed               43
# Generation           1
# Legendary        False
# Name: 9, dtype: object

# %%
df.iloc[[9]]
# Out:
#        Name Type 1  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation  \
# 9  Squirtle  Water  44      48       65       50       64     43           1
#
#    Legendary
# 9      False

# %% [markdown]
# ## To read multiple rows

# %%
df.iloc[10:16]
# Out:
#                        Name Type 1  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 10                Wartortle  Water  59      63       80       65       80
# 11                Blastoise  Water  79      83      100       85      105
# 12  BlastoiseMega Blastoise  Water  79     103      120      135      115
# 13                 Caterpie    Bug  45      30       35       20       20
# 14                  Metapod    Bug  50      20       55       25       25
# 15               Butterfree    Bug  60      45       50       90       80
#
#     Speed  Generation  Legendary
# 10     58           1      False
# 11     78           1      False
# 12     78           1      False
# 13     45           1      False
# 14     30           1      False
# 15     70           1      False

# %% [markdown]
# ## To read a specific name, here 3 is a row index and 1 is a column index

# %%
df.head(2)
# Out:
#         Name Type 1  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation  \
# 0  Bulbasaur  Grass  45      49       49       65       65     45           1
# 1    Ivysaur  Grass  60      62       63       80       80     60           1
#
#    Legendary
# 0      False
# 1      False

# %%
df.iloc[11,0]
# Out:
# 'Blastoise'

# %%
df.head()
# Out:
#                     Name Type 1  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0              Bulbasaur  Grass  45      49       49       65       65     45
# 1                Ivysaur  Grass  60      62       63       80       80     60
# 2               Venusaur  Grass  80      82       83      100      100     80
# 3  VenusaurMega Venusaur  Grass  80     100      123      122      120     80
# 4             Charmander   Fire  39      52       43       60       50     65
#
#    Generation  Legendary
# 0           1      False
# 1           1      False
# 2           1      False
# 3           1      False
# 4           1      False

# %% [markdown]
# ## To see the unique values in a data

# %%
df['Type 1'].unique()
# Out:
# array(['Grass', 'Fire', 'Water', 'Bug', 'Normal', 'Poison', 'Electric',
#        'Ground', 'Fairy', 'Fighting', 'Psychic', 'Rock', 'Ghost', 'Ice',
#        'Dragon', 'Dark', 'Steel', 'Flying'], dtype=object)

# %% [markdown]
# # To see the number of unique categories

# %%
print(len(df['Type 1'].unique()))
# Out:
# 18

# %%
df['Type 1'].nunique()
        #OR
# Out:
# 18

# %%
len(df['Type 1'].unique())
# Out:
# 18

# %% [markdown]
# ## To see the Counts of the category in a data

# %%
df['Type 1'].value_counts() # by default is shows the result in descending order
# Out:
# Type 1
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Rock         44
# Electric     44
# Ground       32
# Ghost        32
# Dragon       32
# Dark         31
# Poison       28
# Fighting     27
# Steel        27
# Ice          24
# Fairy        17
# Flying        4
# Name: count, dtype: int64

# %%
df['Type 1'].mode()
# Out:
# 0    Water
# Name: Type 1, dtype: object

# %% [markdown]
# ## To find the specific information in a data or to apply a condition in a data

# %% [markdown]
# # it is just like the specific rows it's based on textual information
# df[df['Type 1']=='Fire'] #it print only the data of Fire type1 pokemons

# %%
df
# Out:
#                       Name   Type 1  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0                Bulbasaur    Grass  45      49       49       65       65
# 1                  Ivysaur    Grass  60      62       63       80       80
# 2                 Venusaur    Grass  80      82       83      100      100
# 3    VenusaurMega Venusaur    Grass  80     100      123      122      120
# 4               Charmander     Fire  39      52       43       60       50
# ..                     ...      ...  ..     ...      ...      ...      ...
# 795                Diancie     Rock  50     100      150      100      150
# 796    DiancieMega Diancie     Rock  50     160      110      160      110
# 797    HoopaHoopa Confined  Psychic  80     110       60      150      130
# 798     HoopaHoopa Unbound  Psychic  80     160       60      170      130
# 799              Volcanion     Fire  80     110      120      130       90
#
#      Speed  Generation  Legendary
# ...

# %%
df.sort_values(by='HP')
# Out:
#           Name   Type 1   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 316   Shedinja      Bug    1      90       45       30       30     40
# 55     Diglett   Ground   10      55       25       35       45     95
# 381     Feebas    Water   20      15       20       10       55     80
# 388    Duskull    Ghost   20      40       90       30       90     25
# 487   Mime Jr.  Psychic   20      25       45       70       90     60
# ..         ...      ...  ...     ...      ...      ...      ...    ...
# 655  Alomomola    Water  165      75       80       40       45     65
# 351    Wailord    Water  170      90       45       90       45     60
# 217  Wobbuffet  Psychic  190      33       58       33       58     33
# 121    Chansey   Normal  250       5        5       35      105     50
# 261    Blissey   Normal  255      10       10       75      135     55
#
#      Generation  Legendary
# 316           3      False
# 55            1      False
# 381           3      False
# ...

# %% [markdown]
# ## it sort the values in ascending order

# %%
df.sort_values(by='HP',ascending=False)
# Out:
#           Name    Type 1   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 261    Blissey    Normal  255      10       10       75      135     55
# 121    Chansey    Normal  250       5        5       35      105     50
# 217  Wobbuffet   Psychic  190      33       58       33       58     33
# 351    Wailord     Water  170      90       45       90       45     60
# 655  Alomomola     Water  165      75       80       40       45     65
# ..         ...       ...  ...     ...      ...      ...      ...    ...
# 230    Shuckle       Bug   20      10      230       10      230      5
# 139   Magikarp     Water   20      10       55       15       20     80
# 186      Pichu  Electric   20      40       15       35       35     60
# 55     Diglett    Ground   10      55       25       35       45     95
# 316   Shedinja       Bug    1      90       45       30       30     40
#
#      Generation  Legendary
# 261           2      False
# 121           1      False
# ...

# %%
df.sort_values(by='HP',ascending=False)
# Out:
#           Name    Type 1   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 261    Blissey    Normal  255      10       10       75      135     55
# 121    Chansey    Normal  250       5        5       35      105     50
# 217  Wobbuffet   Psychic  190      33       58       33       58     33
# 351    Wailord     Water  170      90       45       90       45     60
# 655  Alomomola     Water  165      75       80       40       45     65
# ..         ...       ...  ...     ...      ...      ...      ...    ...
# 230    Shuckle       Bug   20      10      230       10      230      5
# 139   Magikarp     Water   20      10       55       15       20     80
# 186      Pichu  Electric   20      40       15       35       35     60
# 55     Diglett    Ground   10      55       25       35       45     95
# 316   Shedinja       Bug    1      90       45       30       30     40
#
#      Generation  Legendary
# 261           2      False
# 121           1      False
# ...

# %%
df.sort_values(by='HP')
# Out:
#           Name   Type 1   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 316   Shedinja      Bug    1      90       45       30       30     40
# 55     Diglett   Ground   10      55       25       35       45     95
# 381     Feebas    Water   20      15       20       10       55     80
# 388    Duskull    Ghost   20      40       90       30       90     25
# 487   Mime Jr.  Psychic   20      25       45       70       90     60
# ..         ...      ...  ...     ...      ...      ...      ...    ...
# 655  Alomomola    Water  165      75       80       40       45     65
# 351    Wailord    Water  170      90       45       90       45     60
# 217  Wobbuffet  Psychic  190      33       58       33       58     33
# 121    Chansey   Normal  250       5        5       35      105     50
# 261    Blissey   Normal  255      10       10       75      135     55
#
#      Generation  Legendary
# 316           3      False
# 55            1      False
# 381           3      False
# ...

# %%
df.sort_values(by='HP',ascending=False)
# Out:
#           Name    Type 1   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 261    Blissey    Normal  255      10       10       75      135     55
# 121    Chansey    Normal  250       5        5       35      105     50
# 217  Wobbuffet   Psychic  190      33       58       33       58     33
# 351    Wailord     Water  170      90       45       90       45     60
# 655  Alomomola     Water  165      75       80       40       45     65
# ..         ...       ...  ...     ...      ...      ...      ...    ...
# 230    Shuckle       Bug   20      10      230       10      230      5
# 139   Magikarp     Water   20      10       55       15       20     80
# 186      Pichu  Electric   20      40       15       35       35     60
# 55     Diglett    Ground   10      55       25       35       45     95
# 316   Shedinja       Bug    1      90       45       30       30     40
#
#      Generation  Legendary
# 261           2      False
# 121           1      False
# ...

# %%
df.sort_values(by=['Speed','HP'])
# Out:
#                           Name   Type 1   HP  Attack  Defense  Sp. Atk  \
# 230                    Shuckle      Bug   20      10      230       10
# 495                   Munchlax   Normal  135      85       40       40
# 658                  Ferroseed    Grass   44      50       91       24
# 359                   Trapinch   Ground   45     100       45       45
# 486                     Bonsly     Rock   50      80       95       10
# ..                         ...      ...  ...     ...      ...      ...
# 429         DeoxysAttack Forme  Psychic   50     180       20      180
# 71       AlakazamMega Alakazam  Psychic   55      50       65      175
# 154  AerodactylMega Aerodactyl     Rock   80     135       85       70
# 315                    Ninjask      Bug   61      90       45       50
# 431          DeoxysSpeed Forme  Psychic   50      95       90       95
#
#      Sp. Def  Speed  Generation  Legendary
# 230      230      5           2      False
# ...

# %%
df.sort_values(by=['Speed','HP'],ascending=[False,False])
# Out:
#                           Name   Type 1   HP  Attack  Defense  Sp. Atk  \
# 431          DeoxysSpeed Forme  Psychic   50      95       90       95
# 315                    Ninjask      Bug   61      90       45       50
# 154  AerodactylMega Aerodactyl     Rock   80     135       85       70
# 71       AlakazamMega Alakazam  Psychic   55      50       65      175
# 428         DeoxysNormal Forme  Psychic   50     150       50      150
# ..                         ...      ...  ...     ...      ...      ...
# 486                     Bonsly     Rock   50      80       95       10
# 359                   Trapinch   Ground   45     100       45       45
# 658                  Ferroseed    Grass   44      50       91       24
# 495                   Munchlax   Normal  135      85       40       40
# 230                    Shuckle      Bug   20      10      230       10
#
#      Sp. Def  Speed  Generation  Legendary
# 431       90    180           3       True
# ...

# %%
df.sort_values(by=['HP','Speed'],ascending=[False,True])
# Out:
#           Name   Type 1   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 261    Blissey   Normal  255      10       10       75      135     55
# 121    Chansey   Normal  250       5        5       35      105     50
# 217  Wobbuffet  Psychic  190      33       58       33       58     33
# 351    Wailord    Water  170      90       45       90       45     60
# 655  Alomomola    Water  165      75       80       40       45     65
# ..         ...      ...  ...     ...      ...      ...      ...    ...
# 487   Mime Jr.  Psychic   20      25       45       70       90     60
# 139   Magikarp    Water   20      10       55       15       20     80
# 381     Feebas    Water   20      15       20       10       55     80
# 55     Diglett   Ground   10      55       25       35       45     95
# 316   Shedinja      Bug    1      90       45       30       30     40
#
#      Generation  Legendary
# 261           2      False
# 121           1      False
# 217           2      False
# ...

# %%
df.sort_values(by='Attack')
# Out:
#                         Name   Type 1   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 488                  Happiny   Normal  100       5        5       15       65
# 121                  Chansey   Normal  250       5        5       35      105
# 139                 Magikarp    Water   20      10       55       15       20
# 261                  Blissey   Normal  255      10       10       75      135
# 230                  Shuckle      Bug   20      10      230       10      230
# ..                       ...      ...  ...     ...      ...      ...      ...
# 424    GroudonPrimal Groudon   Ground  100     180      160      150       90
# 426    RayquazaMega Rayquaza   Dragon  105     180      100      180      100
# 429       DeoxysAttack Forme  Psychic   50     180       20      180       20
# 232  HeracrossMega Heracross      Bug   80     185      115       40      105
# 163      MewtwoMega Mewtwo X  Psychic  106     190      100      154      100
#
# ...

# %%
df.sort_values(by='Attack',ascending=False)
# Out:
#                         Name   Type 1   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 163      MewtwoMega Mewtwo X  Psychic  106     190      100      154      100
# 232  HeracrossMega Heracross      Bug   80     185      115       40      105
# 429       DeoxysAttack Forme  Psychic   50     180       20      180       20
# 426    RayquazaMega Rayquaza   Dragon  105     180      100      180      100
# 424    GroudonPrimal Groudon   Ground  100     180      160      150       90
# ..                       ...      ...  ...     ...      ...      ...      ...
# 230                  Shuckle      Bug   20      10      230       10      230
# 261                  Blissey   Normal  255      10       10       75      135
# 139                 Magikarp    Water   20      10       55       15       20
# 121                  Chansey   Normal  250       5        5       35      105
# 488                  Happiny   Normal  100       5        5       15       65
#
# ...

# %%
df.sort_values(by='Name')
# Out:
#                         Name   Type 1   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 510                Abomasnow    Grass   90      92       75       92       85
# 511  AbomasnowMega Abomasnow    Grass   90     132      105      132      105
# 68                      Abra  Psychic   25      20       15      105       55
# 392                    Absol     Dark   65     130       60       75       60
# 393          AbsolMega Absol     Dark   65     150       60      115       60
# ..                       ...      ...  ...     ...      ...      ...      ...
# 632                  Zoroark     Dark   60     105       60      120       60
# 631                    Zorua     Dark   40      65       40       80       40
# 46                     Zubat   Poison   40      45       35       30       40
# 695                 Zweilous     Dark   72      85       70       65       70
# 794         Zygarde50% Forme   Dragon  108     100      121       81       95
#
# ...

# %%
df.sort_values(by='Name',ascending=False)
# Out:
#                         Name   Type 1   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 794         Zygarde50% Forme   Dragon  108     100      121       81       95
# 695                 Zweilous     Dark   72      85       70       65       70
# 46                     Zubat   Poison   40      45       35       30       40
# 631                    Zorua     Dark   40      65       40       80       40
# 632                  Zoroark     Dark   60     105       60      120       60
# ..                       ...      ...  ...     ...      ...      ...      ...
# 393          AbsolMega Absol     Dark   65     150       60      115       60
# 392                    Absol     Dark   65     130       60       75       60
# 68                      Abra  Psychic   25      20       15      105       55
# 511  AbomasnowMega Abomasnow    Grass   90     132      105      132      105
# 510                Abomasnow    Grass   90      92       75       92       85
#
# ...

# %%
df.sort_values(by=['Attack','Defense'])
# Out:
#                         Name   Type 1   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 121                  Chansey   Normal  250       5        5       35      105
# 488                  Happiny   Normal  100       5        5       15       65
# 261                  Blissey   Normal  255      10       10       75      135
# 139                 Magikarp    Water   20      10       55       15       20
# 230                  Shuckle      Bug   20      10      230       10      230
# ..                       ...      ...  ...     ...      ...      ...      ...
# 429       DeoxysAttack Forme  Psychic   50     180       20      180       20
# 426    RayquazaMega Rayquaza   Dragon  105     180      100      180      100
# 424    GroudonPrimal Groudon   Ground  100     180      160      150       90
# 232  HeracrossMega Heracross      Bug   80     185      115       40      105
# 163      MewtwoMega Mewtwo X  Psychic  106     190      100      154      100
#
# ...

# %%
df.sort_values(by=['Defense','Attack'],ascending=[False,False])
# Out:
#                     Name   Type 1   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 333    AggronMega Aggron    Steel   70     140      230       60       80
# 224  SteelixMega Steelix    Steel   75     125      230       55       95
# 230              Shuckle      Bug   20      10      230       10      230
# 414             Regirock     Rock   80     100      200       50      100
# 223              Steelix    Steel   75      85      200       55       65
# ..                   ...      ...  ...     ...      ...      ...      ...
# 257             Smoochum      Ice   45      30       15       85       65
# 68                  Abra  Psychic   25      20       15      105       55
# 261              Blissey   Normal  255      10       10       75      135
# 121              Chansey   Normal  250       5        5       35      105
# 488              Happiny   Normal  100       5        5       15       65
#
#      Speed  Generation  Legendary
# 333     50           3      False
# ...

# %%
df.sort_values(by=['Defense','Attack'],ascending=[True,False])
# Out:
#                     Name    Type 1   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 121              Chansey    Normal  250       5        5       35      105
# 488              Happiny    Normal  100       5        5       15       65
# 261              Blissey    Normal  255      10       10       75      135
# 186                Pichu  Electric   20      40       15       35       35
# 188            Igglybuff    Normal   90      30       15       40       20
# ..                   ...       ...  ...     ...      ...      ...      ...
# 414             Regirock      Rock   80     100      200       50      100
# 223              Steelix     Steel   75      85      200       55       65
# 333    AggronMega Aggron     Steel   70     140      230       60       80
# 224  SteelixMega Steelix     Steel   75     125      230       55       95
# 230              Shuckle       Bug   20      10      230       10      230
#
#      Speed  Generation  Legendary
# ...

# %%
df.sort_values(['Attack'])
#df.sort_values(by='Attack')
# Out:
#                         Name   Type 1   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 488                  Happiny   Normal  100       5        5       15       65
# 121                  Chansey   Normal  250       5        5       35      105
# 139                 Magikarp    Water   20      10       55       15       20
# 261                  Blissey   Normal  255      10       10       75      135
# 230                  Shuckle      Bug   20      10      230       10      230
# ..                       ...      ...  ...     ...      ...      ...      ...
# 424    GroudonPrimal Groudon   Ground  100     180      160      150       90
# 426    RayquazaMega Rayquaza   Dragon  105     180      100      180      100
# 429       DeoxysAttack Forme  Psychic   50     180       20      180       20
# 232  HeracrossMega Heracross      Bug   80     185      115       40      105
# 163      MewtwoMega Mewtwo X  Psychic  106     190      100      154      100
#
# ...

# %%
df['Attack'].min()
# Out:
# 5

# %% [markdown]
# ## it sort the values in descending order

# %%
df.sort_values(['Name'],ascending=False)
# Out:
#                         Name   Type 1   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 794         Zygarde50% Forme   Dragon  108     100      121       81       95
# 695                 Zweilous     Dark   72      85       70       65       70
# 46                     Zubat   Poison   40      45       35       30       40
# 631                    Zorua     Dark   40      65       40       80       40
# 632                  Zoroark     Dark   60     105       60      120       60
# ..                       ...      ...  ...     ...      ...      ...      ...
# 393          AbsolMega Absol     Dark   65     150       60      115       60
# 392                    Absol     Dark   65     130       60       75       60
# 68                      Abra  Psychic   25      20       15      105       55
# 511  AbomasnowMega Abomasnow    Grass   90     132      105      132      105
# 510                Abomasnow    Grass   90      92       75       92       85
#
# ...

# %%
df.sort_values(['Attack'],ascending=False)
# Out:
#                         Name   Type 1   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 163      MewtwoMega Mewtwo X  Psychic  106     190      100      154      100
# 232  HeracrossMega Heracross      Bug   80     185      115       40      105
# 429       DeoxysAttack Forme  Psychic   50     180       20      180       20
# 426    RayquazaMega Rayquaza   Dragon  105     180      100      180      100
# 424    GroudonPrimal Groudon   Ground  100     180      160      150       90
# ..                       ...      ...  ...     ...      ...      ...      ...
# 230                  Shuckle      Bug   20      10      230       10      230
# 261                  Blissey   Normal  255      10       10       75      135
# 139                 Magikarp    Water   20      10       55       15       20
# 121                  Chansey   Normal  250       5        5       35      105
# 488                  Happiny   Normal  100       5        5       15       65
#
# ...

# %% [markdown]
# ## when two columns name is given then it sort the values according to the first column

# %%
df.sort_values(["Attack","Name"])
# Out:
#                         Name   Type 1   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 121                  Chansey   Normal  250       5        5       35      105
# 488                  Happiny   Normal  100       5        5       15       65
# 261                  Blissey   Normal  255      10       10       75      135
# 139                 Magikarp    Water   20      10       55       15       20
# 230                  Shuckle      Bug   20      10      230       10      230
# ..                       ...      ...  ...     ...      ...      ...      ...
# 429       DeoxysAttack Forme  Psychic   50     180       20      180       20
# 424    GroudonPrimal Groudon   Ground  100     180      160      150       90
# 426    RayquazaMega Rayquaza   Dragon  105     180      100      180      100
# 232  HeracrossMega Heracross      Bug   80     185      115       40      105
# 163      MewtwoMega Mewtwo X  Psychic  106     190      100      154      100
#
# ...

# %%
df['row_sum']=df.iloc[:,2:8].sum(axis=1)

# %%
df
# Out:
#                       Name   Type 1  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0                Bulbasaur    Grass  45      49       49       65       65
# 1                  Ivysaur    Grass  60      62       63       80       80
# 2                 Venusaur    Grass  80      82       83      100      100
# 3    VenusaurMega Venusaur    Grass  80     100      123      122      120
# 4               Charmander     Fire  39      52       43       60       50
# ..                     ...      ...  ..     ...      ...      ...      ...
# 795                Diancie     Rock  50     100      150      100      150
# 796    DiancieMega Diancie     Rock  50     160      110      160      110
# 797    HoopaHoopa Confined  Psychic  80     110       60      150      130
# 798     HoopaHoopa Unbound  Psychic  80     160       60      170      130
# 799              Volcanion     Fire  80     110      120      130       90
#
#      Speed  Generation  Legendary  row_sum
# ...

# %%
L=[5,5,10,10,10]
l2=[100,5,27,56,100]

# %%
d=pd.DataFrame({'x':L,'y':l2})
d
# Out:
#     x    y
# 0   5  100
# 1   5    5
# 2  10   27
# 3  10   56
# 4  10  100

# %%
d.sort_values(by=['x','y'],ascending=[True,True])
# Out:
#     x    y
# 1   5    5
# 0   5  100
# 2  10   27
# 3  10   56
# 4  10  100

# %%
d.sort_values(by=['x','y'],ascending=[False,False])
# Out:
#     x    y
# 4  10  100
# 3  10   56
# 2  10   27
# 0   5  100
# 1   5    5

# %%
d.sort_values(by=['x','y'],ascending=[True,False])
# Out:
#     x    y
# 0   5  100
# 1   5    5
# 4  10  100
# 3  10   56
# 2  10   27

# %%
d.sort_values(by=['x','y'],ascending=[False,True])
# Out:
#     x    y
# 2  10   27
# 3  10   56
# 4  10  100
# 1   5    5
# 0   5  100

# %%
df.iloc[0:,2:8]
# Out:
#      HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# 0    45      49       49       65       65     45
# 1    60      62       63       80       80     60
# 2    80      82       83      100      100     80
# 3    80     100      123      122      120     80
# 4    39      52       43       60       50     65
# ..   ..     ...      ...      ...      ...    ...
# 795  50     100      150      100      150     50
# 796  50     160      110      160      110    110
# 797  80     110       60      150      130     70
# 798  80     160       60      170      130     80
# 799  80     110      120      130       90     70
#
# [800 rows x 6 columns]

# %%
df['Total']=df.iloc[0:,2:8].sum(axis=1)

# %%
df
# Out:
#                       Name   Type 1  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0                Bulbasaur    Grass  45      49       49       65       65
# 1                  Ivysaur    Grass  60      62       63       80       80
# 2                 Venusaur    Grass  80      82       83      100      100
# 3    VenusaurMega Venusaur    Grass  80     100      123      122      120
# 4               Charmander     Fire  39      52       43       60       50
# ..                     ...      ...  ..     ...      ...      ...      ...
# 795                Diancie     Rock  50     100      150      100      150
# 796    DiancieMega Diancie     Rock  50     160      110      160      110
# 797    HoopaHoopa Confined  Psychic  80     110       60      150      130
# 798     HoopaHoopa Unbound  Psychic  80     160       60      170      130
# 799              Volcanion     Fire  80     110      120      130       90
#
#      Speed  Generation  Legendary  row_sum  Total
# ...

# %%
col=list(df.columns)
col
# Out:
# ['Name',
#  'Type 1',
#  'HP',
#  'Attack',
#  'Defense',
#  'Sp. Atk',
#  'Sp. Def',
#  'Speed',
#  'Generation',
#  'Legendary',
#  'row_sum',
#  'Total']

# %%
[col[-1]]
# Out:
# ['Total']

# %%
df=df[col[0:2]+[col[-1]]+col[2:10]]

# %%
df
# Out:
#                       Name   Type 1  Total  HP  Attack  Defense  Sp. Atk  \
# 0                Bulbasaur    Grass    318  45      49       49       65
# 1                  Ivysaur    Grass    405  60      62       63       80
# 2                 Venusaur    Grass    525  80      82       83      100
# 3    VenusaurMega Venusaur    Grass    625  80     100      123      122
# 4               Charmander     Fire    309  39      52       43       60
# ..                     ...      ...    ...  ..     ...      ...      ...
# 795                Diancie     Rock    600  50     100      150      100
# 796    DiancieMega Diancie     Rock    700  50     160      110      160
# 797    HoopaHoopa Confined  Psychic    600  80     110       60      150
# 798     HoopaHoopa Unbound  Psychic    680  80     160       60      170
# 799              Volcanion     Fire    600  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 0         65     45           1      False
# ...

# %%
df.columns
# Out:
# Index(['Name', 'Type 1', 'Total', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
df=df[['Name', 'Type 1',  'Total','HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def',
       'Speed', 'Generation', 'Legendary']]
df
# Out:
#                       Name   Type 1  Total  HP  Attack  Defense  Sp. Atk  \
# 0                Bulbasaur    Grass    318  45      49       49       65
# 1                  Ivysaur    Grass    405  60      62       63       80
# 2                 Venusaur    Grass    525  80      82       83      100
# 3    VenusaurMega Venusaur    Grass    625  80     100      123      122
# 4               Charmander     Fire    309  39      52       43       60
# ..                     ...      ...    ...  ..     ...      ...      ...
# 795                Diancie     Rock    600  50     100      150      100
# 796    DiancieMega Diancie     Rock    700  50     160      110      160
# 797    HoopaHoopa Confined  Psychic    600  80     110       60      150
# 798     HoopaHoopa Unbound  Psychic    680  80     160       60      170
# 799              Volcanion     Fire    600  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 0         65     45           1      False
# ...

# %%
df
# Out:
#                       Name   Type 1  Total  HP  Attack  Defense  Sp. Atk  \
# 0                Bulbasaur    Grass    318  45      49       49       65
# 1                  Ivysaur    Grass    405  60      62       63       80
# 2                 Venusaur    Grass    525  80      82       83      100
# 3    VenusaurMega Venusaur    Grass    625  80     100      123      122
# 4               Charmander     Fire    309  39      52       43       60
# ..                     ...      ...    ...  ..     ...      ...      ...
# 795                Diancie     Rock    600  50     100      150      100
# 796    DiancieMega Diancie     Rock    700  50     160      110      160
# 797    HoopaHoopa Confined  Psychic    600  80     110       60      150
# 798     HoopaHoopa Unbound  Psychic    680  80     160       60      170
# 799              Volcanion     Fire    600  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 0         65     45           1      False
# ...

# %%
df['Type 1']=='Rock'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 795     True
# 796     True
# 797    False
# 798    False
# 799    False
# Name: Type 1, Length: 800, dtype: bool

# %%
df[df['Type 1']=='Rock']
# Out:
#                           Name Type 1  Total   HP  Attack  Defense  Sp. Atk  \
# 80                     Geodude   Rock    300   40      80      100       30
# 81                    Graveler   Rock    390   55      95      115       45
# 82                       Golem   Rock    495   80     120      130       55
# 103                       Onix   Rock    385   35      45      160       30
# 149                    Omanyte   Rock    355   35      40      100       90
# 150                    Omastar   Rock    495   70      60      125      115
# 151                     Kabuto   Rock    355   30      80       90       55
# 152                   Kabutops   Rock    495   60     115      105       65
# 153                 Aerodactyl   Rock    515   80     105       65       60
# 154  AerodactylMega Aerodactyl   Rock    615   80     135       85       70
# 200                  Sudowoodo   Rock    410   70     100      115       30
# ...

# %%
df['Attack']>160
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 795    False
# 796    False
# 797    False
# 798    False
# 799    False
# Name: Attack, Length: 800, dtype: bool

# %%
df[df['Attack']>160]
# Out:
#                         Name   Type 1  Total   HP  Attack  Defense  Sp. Atk  \
# 163      MewtwoMega Mewtwo X  Psychic    780  106     190      100      154
# 232  HeracrossMega Heracross      Bug    600   80     185      115       40
# 268  TyranitarMega Tyranitar     Rock    700  100     164      150       95
# 387      BanetteMega Banette    Ghost    555   64     165       75       93
# 424    GroudonPrimal Groudon   Ground    770  100     180      160      150
# 426    RayquazaMega Rayquaza   Dragon    780  105     180      100      180
# 429       DeoxysAttack Forme  Psychic    600   50     180       20      180
# 454                Rampardos     Rock    495   97     165       60       65
# 494    GarchompMega Garchomp   Dragon    700  108     170      115      120
# 527      GalladeMega Gallade  Psychic    618   68     165       95       65
# 711       KyuremBlack Kyurem   Dragon    700  125     170      100      120
#
#      Sp. Def  Speed  Generation  Legendary
# ...

# %%
df[(df['Type 1']=='Flying') | (df['Type 1']=='Fairy')]
# Out:
#                         Name  Type 1  Total   HP  Attack  Defense  Sp. Atk  \
# 40                  Clefairy   Fairy    323   70      45       48       60
# 41                  Clefable   Fairy    483   95      70       73       95
# 187                   Cleffa   Fairy    218   50      25       28       45
# 189                   Togepi   Fairy    245   35      20       65       40
# 190                  Togetic   Fairy    405   55      40       85       80
# 225                 Snubbull   Fairy    300   60      80       50       40
# 226                 Granbull   Fairy    450   90     120       75       60
# 519                 Togekiss   Fairy    545   85      50       95      120
# 702  TornadusIncarnate Forme  Flying    580   79     115       70      125
# 703    TornadusTherian Forme  Flying    580   79     100       80      110
# 737                  Flabébé   Fairy    303   44      38       39       61
# ...

# %%
df[(df['Type 1']!='Rock') & (df['Total']!=500)]
# Out:
#                       Name   Type 1  Total   HP  Attack  Defense  Sp. Atk  \
# 0                Bulbasaur    Grass    318   45      49       49       65
# 1                  Ivysaur    Grass    405   60      62       63       80
# 2                 Venusaur    Grass    525   80      82       83      100
# 3    VenusaurMega Venusaur    Grass    625   80     100      123      122
# 4               Charmander     Fire    309   39      52       43       60
# ..                     ...      ...    ...  ...     ...      ...      ...
# 793                Yveltal     Dark    680  126     131       95      131
# 794       Zygarde50% Forme   Dragon    600  108     100      121       81
# 797    HoopaHoopa Confined  Psychic    600   80     110       60      150
# 798     HoopaHoopa Unbound  Psychic    680   80     160       60      170
# 799              Volcanion     Fire    600   80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# ...

# %% [markdown]
# ## here it shows both column in descending order

# %%
df.sort_values(["Attack",'Name'],ascending=[True,False])
# Out:
#                         Name   Type 1  Total   HP  Attack  Defense  Sp. Atk  \
# 488                  Happiny   Normal    220  100       5        5       15
# 121                  Chansey   Normal    450  250       5        5       35
# 230                  Shuckle      Bug    505   20      10      230       10
# 139                 Magikarp    Water    200   20      10       55       15
# 261                  Blissey   Normal    540  255      10       10       75
# ..                       ...      ...    ...  ...     ...      ...      ...
# 426    RayquazaMega Rayquaza   Dragon    780  105     180      100      180
# 424    GroudonPrimal Groudon   Ground    770  100     180      160      150
# 429       DeoxysAttack Forme  Psychic    600   50     180       20      180
# 232  HeracrossMega Heracross      Bug    600   80     185      115       40
# 163      MewtwoMega Mewtwo X  Psychic    780  106     190      100      154
#
#      Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.sort_values(["Attack",'Name'],ascending=[True,True])
# Out:
#                         Name   Type 1  Total   HP  Attack  Defense  Sp. Atk  \
# 121                  Chansey   Normal    450  250       5        5       35
# 488                  Happiny   Normal    220  100       5        5       15
# 261                  Blissey   Normal    540  255      10       10       75
# 139                 Magikarp    Water    200   20      10       55       15
# 230                  Shuckle      Bug    505   20      10      230       10
# ..                       ...      ...    ...  ...     ...      ...      ...
# 429       DeoxysAttack Forme  Psychic    600   50     180       20      180
# 424    GroudonPrimal Groudon   Ground    770  100     180      160      150
# 426    RayquazaMega Rayquaza   Dragon    780  105     180      100      180
# 232  HeracrossMega Heracross      Bug    600   80     185      115       40
# 163      MewtwoMega Mewtwo X  Psychic    780  106     190      100      154
#
#      Sp. Def  Speed  Generation  Legendary
# ...

# %% [markdown]
# ## here it shows both column in ascending order¶

# %%
df.sort_values(["Type 1","Attack"])
# Out:
#                       Name Type 1  Total   HP  Attack  Defense  Sp. Atk  \
# 230                Shuckle    Bug    505   20      10      230       10
# 14                 Metapod    Bug    205   50      20       55       25
# 179                 Ledyba    Bug    265   40      20       30       40
# 733                 Spewpa    Bug    213   45      22       60       27
# 17                  Kakuna    Bug    205   45      25       50       25
# ..                     ...    ...    ...  ...     ...      ...      ...
# 107                Kingler  Water    475   55     130      115       50
# 349  SharpedoMega Sharpedo  Water    560   70     140       70      110
# 283  SwampertMega Swampert  Water    635  100     150      110       95
# 422    KyogrePrimal Kyogre  Water    770  100     150       90      180
# 141  GyaradosMega Gyarados  Water    640   95     155      109       70
#
#      Sp. Def  Speed  Generation  Legendary
# 230      230      5           2      False
# ...

# %%
df['total'] = df.iloc[:,2:-2].sum(axis=1)

# %%
df
# Out:
#                       Name   Type 1  Total  HP  Attack  Defense  Sp. Atk  \
# 0                Bulbasaur    Grass    318  45      49       49       65
# 1                  Ivysaur    Grass    405  60      62       63       80
# 2                 Venusaur    Grass    525  80      82       83      100
# 3    VenusaurMega Venusaur    Grass    625  80     100      123      122
# 4               Charmander     Fire    309  39      52       43       60
# ..                     ...      ...    ...  ..     ...      ...      ...
# 795                Diancie     Rock    600  50     100      150      100
# 796    DiancieMega Diancie     Rock    700  50     160      110      160
# 797    HoopaHoopa Confined  Psychic    600  80     110       60      150
# 798     HoopaHoopa Unbound  Psychic    680  80     160       60      170
# 799              Volcanion     Fire    600  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary  total
# ...

# %%
df.columns
# Out:
# Index(['Name', 'Type 1', 'Total', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary', 'total'],
#       dtype='object')

# %%
df=df[['Name', 'Type 1','total', 'HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def',
       'Speed', 'Generation', 'Legendary', ]]
df
# Out:
#                       Name   Type 1  total  HP  Attack  Defense  Sp. Atk  \
# 0                Bulbasaur    Grass    636  45      49       49       65
# 1                  Ivysaur    Grass    810  60      62       63       80
# 2                 Venusaur    Grass   1050  80      82       83      100
# 3    VenusaurMega Venusaur    Grass   1250  80     100      123      122
# 4               Charmander     Fire    618  39      52       43       60
# ..                     ...      ...    ...  ..     ...      ...      ...
# 795                Diancie     Rock   1200  50     100      150      100
# 796    DiancieMega Diancie     Rock   1400  50     160      110      160
# 797    HoopaHoopa Confined  Psychic   1200  80     110       60      150
# 798     HoopaHoopa Unbound  Psychic   1360  80     160       60      170
# 799              Volcanion     Fire   1200  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 0         65     45           1      False
# ...

# %%
df[(df['Type 1']=='Fairy') & (df['Attack']>100)]
# Out:
#          Name Type 1  total   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 226  Granbull  Fairy    900   90     120       75       60       60     45
# 792   Xerneas  Fairy   1360  126     131       95      131       98     99
#
#      Generation  Legendary
# 226           2      False
# 792           6       True

# %%
df['total']=df.iloc[:,2:8].sum(axis=1)
df
# Out:
# /tmp/ipython-input-96-1256480402.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['total']=df.iloc[:,2:8].sum(axis=1)
#                       Name   Type 1  total  HP  Attack  Defense  Sp. Atk  \
# 0                Bulbasaur    Grass    909  45      49       49       65
# 1                  Ivysaur    Grass   1155  60      62       63       80
# 2                 Venusaur    Grass   1495  80      82       83      100
# 3    VenusaurMega Venusaur    Grass   1795  80     100      123      122
# 4               Charmander     Fire    862  39      52       43       60
# ..                     ...      ...    ...  ..     ...      ...      ...
# 795                Diancie     Rock   1750  50     100      150      100
# ...

# %%
df
# Out:
#                       Name   Type 1  total  HP  Attack  Defense  Sp. Atk  \
# 0                Bulbasaur    Grass    909  45      49       49       65
# 1                  Ivysaur    Grass   1155  60      62       63       80
# 2                 Venusaur    Grass   1495  80      82       83      100
# 3    VenusaurMega Venusaur    Grass   1795  80     100      123      122
# 4               Charmander     Fire    862  39      52       43       60
# ..                     ...      ...    ...  ..     ...      ...      ...
# 795                Diancie     Rock   1750  50     100      150      100
# 796    DiancieMega Diancie     Rock   1990  50     160      110      160
# 797    HoopaHoopa Confined  Psychic   1730  80     110       60      150
# 798     HoopaHoopa Unbound  Psychic   1960  80     160       60      170
# 799              Volcanion     Fire   1730  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 0         65     45           1      False
# ...

# %%
df.columns
# Out:
# Index(['Name', 'Type 1', 'total', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
df=df[['Name', 'Type 1', 'total','HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def',
       'Speed', 'Generation', 'Legendary']]
df
# Out:
#                       Name   Type 1  total  HP  Attack  Defense  Sp. Atk  \
# 0                Bulbasaur    Grass    909  45      49       49       65
# 1                  Ivysaur    Grass   1155  60      62       63       80
# 2                 Venusaur    Grass   1495  80      82       83      100
# 3    VenusaurMega Venusaur    Grass   1795  80     100      123      122
# 4               Charmander     Fire    862  39      52       43       60
# ..                     ...      ...    ...  ..     ...      ...      ...
# 795                Diancie     Rock   1750  50     100      150      100
# 796    DiancieMega Diancie     Rock   1990  50     160      110      160
# 797    HoopaHoopa Confined  Psychic   1730  80     110       60      150
# 798     HoopaHoopa Unbound  Psychic   1960  80     160       60      170
# 799              Volcanion     Fire   1730  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 0         65     45           1      False
# ...

# %%
df[df['Type 1']=='Flying']
# Out:
#                         Name  Type 1  total  HP  Attack  Defense  Sp. Atk  \
# 702  TornadusIncarnate Forme  Flying   1629  79     115       70      125
# 703    TornadusTherian Forme  Flying   1619  79     100       80      110
# 790                   Noibat  Flying    680  40      30       35       45
# 791                  Noivern  Flying   1482  85      70       80       97
#
#      Sp. Def  Speed  Generation  Legendary
# 702       80    111           5       True
# 703       90    121           5       True
# 790       40     55           6      False
# 791       80    123           6      False

# %%
df[df['Attack']>180]
# Out:
#                         Name   Type 1  total   HP  Attack  Defense  Sp. Atk  \
# 163      MewtwoMega Mewtwo X  Psychic   2210  106     190      100      154
# 232  HeracrossMega Heracross      Bug   1725   80     185      115       40
#
#      Sp. Def  Speed  Generation  Legendary
# 163      100    130           1       True
# 232      105     75           2      False

# %%
df[(df['Type 1']=='Fire') & (df['Attack']>100)]
# Out:
#                           Name Type 1  total   HP  Attack  Defense  Sp. Atk  \
# 7    CharizardMega Charizard X   Fire   1802   78     130      111      130
# 8    CharizardMega Charizard Y   Fire   1802   78     104       78      159
# 64                    Arcanine   Fire   1570   90     110       80      100
# 147                    Flareon   Fire   1510   65     130       60       95
# 263                      Entei   Fire   1640  115     115       85       90
# 270                      Ho-oh   Fire   1950  106     130       90      110
# 278                   Blaziken   Fire   1510   80     120       70      110
# 279      BlazikenMega Blaziken   Fire   1790   80     160       80      130
# 354      CameruptMega Camerupt   Fire   1660   70     120      100      145
# 437                  Infernape   Fire   1494   76     104       71      104
# 559                     Emboar   Fire   1519  110     123       65      100
# ...

# %%
df['total']=df.iloc[:,2:8].sum(axis=1)

# %%
df
# Out:
#                       Name   Type 1  total  HP  Attack  Defense  Sp. Atk  \
# 0                Bulbasaur    Grass   1182  45      49       49       65
# 1                  Ivysaur    Grass   1500  60      62       63       80
# 2                 Venusaur    Grass   1940  80      82       83      100
# 3    VenusaurMega Venusaur    Grass   2340  80     100      123      122
# 4               Charmander     Fire   1106  39      52       43       60
# ..                     ...      ...    ...  ..     ...      ...      ...
# 795                Diancie     Rock   2300  50     100      150      100
# 796    DiancieMega Diancie     Rock   2580  50     160      110      160
# 797    HoopaHoopa Confined  Psychic   2260  80     110       60      150
# 798     HoopaHoopa Unbound  Psychic   2560  80     160       60      170
# 799              Volcanion     Fire   2260  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 0         65     45           1      False
# ...

# %%
col=list(df.columns)
print(col)
# Out:
# ['Name', 'Type 1', 'total', 'HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary']

# %%
col[2:-1]
# Out:
# ['total',
#  'HP',
#  'Attack',
#  'Defense',
#  'Sp. Atk',
#  'Sp. Def',
#  'Speed',
#  'Generation']

# %%
df[col[0:2]+[col[-1]]+col[2:-1]]
# Out:
#                       Name   Type 1  Legendary  total  HP  Attack  Defense  \
# 0                Bulbasaur    Grass      False   1182  45      49       49
# 1                  Ivysaur    Grass      False   1500  60      62       63
# 2                 Venusaur    Grass      False   1940  80      82       83
# 3    VenusaurMega Venusaur    Grass      False   2340  80     100      123
# 4               Charmander     Fire      False   1106  39      52       43
# ..                     ...      ...        ...    ...  ..     ...      ...
# 795                Diancie     Rock       True   2300  50     100      150
# 796    DiancieMega Diancie     Rock       True   2580  50     160      110
# 797    HoopaHoopa Confined  Psychic       True   2260  80     110       60
# 798     HoopaHoopa Unbound  Psychic       True   2560  80     160       60
# 799              Volcanion     Fire       True   2260  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation
# ...

# %%
[col[-1]]
# Out:
# ['Legendary']

# %%
df1=df[col[0:2]+[col[-1]]+col[2:-1]]
df1
# Out:
#                       Name   Type 1  Legendary  total  HP  Attack  Defense  \
# 0                Bulbasaur    Grass      False   1182  45      49       49
# 1                  Ivysaur    Grass      False   1500  60      62       63
# 2                 Venusaur    Grass      False   1940  80      82       83
# 3    VenusaurMega Venusaur    Grass      False   2340  80     100      123
# 4               Charmander     Fire      False   1106  39      52       43
# ..                     ...      ...        ...    ...  ..     ...      ...
# 795                Diancie     Rock       True   2300  50     100      150
# 796    DiancieMega Diancie     Rock       True   2580  50     160      110
# 797    HoopaHoopa Confined  Psychic       True   2260  80     110       60
# 798     HoopaHoopa Unbound  Psychic       True   2560  80     160       60
# 799              Volcanion     Fire       True   2260  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation
# ...

# %% [markdown]
# # Making changes to  the Data

# %%
# import warnings
# warnings.filterwarnings('ignore')

# %%
#Here i am added the columns HP, Attack, Defense, Sp.Atk, Sp.Def,Speed and named it as Total
#first input is going to colon which means all rows everything[:]
#then count the column here HP is the 2 column upto 8 column speed[:,2:8]
#then define the axis along which you want to add here axis=1 means column wise


df['Total']=df.iloc[:,2:8].sum(axis=1)
df
# Out:
#                       Name   Type 1  total  HP  Attack  Defense  Sp. Atk  \
# 0                Bulbasaur    Grass   1182  45      49       49       65
# 1                  Ivysaur    Grass   1500  60      62       63       80
# 2                 Venusaur    Grass   1940  80      82       83      100
# 3    VenusaurMega Venusaur    Grass   2340  80     100      123      122
# 4               Charmander     Fire   1106  39      52       43       60
# ..                     ...      ...    ...  ..     ...      ...      ...
# 795                Diancie     Rock   2300  50     100      150      100
# 796    DiancieMega Diancie     Rock   2580  50     160      110      160
# 797    HoopaHoopa Confined  Psychic   2260  80     110       60      150
# 798     HoopaHoopa Unbound  Psychic   2560  80     160       60      170
# 799              Volcanion     Fire   2260  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary  Total
# ...

# %%
col=list(df.columns)
col
# Out:
# ['Name',
#  'Type 1',
#  'total',
#  'HP',
#  'Attack',
#  'Defense',
#  'Sp. Atk',
#  'Sp. Def',
#  'Speed',
#  'Generation',
#  'Legendary',
#  'Total']

# %%
df[col[0:5]+[col[-4]]+col[5:7]+col[8:]]
# Out:
#                       Name   Type 1  total  HP  Attack  Speed  Defense  \
# 0                Bulbasaur    Grass   1182  45      49     45       49
# 1                  Ivysaur    Grass   1500  60      62     60       63
# 2                 Venusaur    Grass   1940  80      82     80       83
# 3    VenusaurMega Venusaur    Grass   2340  80     100     80      123
# 4               Charmander     Fire   1106  39      52     65       43
# ..                     ...      ...    ...  ..     ...    ...      ...
# 795                Diancie     Rock   2300  50     100     50      150
# 796    DiancieMega Diancie     Rock   2580  50     160    110      110
# 797    HoopaHoopa Confined  Psychic   2260  80     110     70       60
# 798     HoopaHoopa Unbound  Psychic   2560  80     160     80       60
# 799              Volcanion     Fire   2260  80     110     70      120
#
#      Sp. Atk  Speed  Generation  Legendary  Total
# 0         65     45           1      False   1455
# ...

# %%
marks=np.array([[50,80,90,45,33,78,92]])
marks
# Out:
# array([[50, 80, 90, 45, 33, 78, 92]])

# %%
marks>70
# Out:
# array([[False,  True,  True, False, False,  True,  True]])

# %%
marks[marks>70]
# Out:
# array([80, 90, 78, 92])

# %%
df['Type 1']=='Flying'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 795    False
# 796    False
# 797    False
# 798    False
# 799    False
# Name: Type 1, Length: 800, dtype: bool

# %%
df
# Out:
#                       Name   Type 1  total  HP  Attack  Defense  Sp. Atk  \
# 0                Bulbasaur    Grass   1182  45      49       49       65
# 1                  Ivysaur    Grass   1500  60      62       63       80
# 2                 Venusaur    Grass   1940  80      82       83      100
# 3    VenusaurMega Venusaur    Grass   2340  80     100      123      122
# 4               Charmander     Fire   1106  39      52       43       60
# ..                     ...      ...    ...  ..     ...      ...      ...
# 795                Diancie     Rock   2300  50     100      150      100
# 796    DiancieMega Diancie     Rock   2580  50     160      110      160
# 797    HoopaHoopa Confined  Psychic   2260  80     110       60      150
# 798     HoopaHoopa Unbound  Psychic   2560  80     160       60      170
# 799              Volcanion     Fire   2260  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary  Total
# ...

# %%
df.groupby(['Type 1'])['Attack'].max().sort_values(ascending=False)
# Out:
# Type 1
# Psychic     190
# Bug         185
# Ground      180
# Dragon      180
# Rock        165
# Ghost       165
# Fire        160
# Normal      160
# Water       155
# Dark        150
# Steel       150
# Fighting    145
# Grass       132
# Fairy       131
# Ice         130
# Electric    123
# Flying      115
# Poison      106
# Name: Attack, dtype: int64

# %%
df.groupby(['Type 1'])['Attack'].sum().reset_index().sort_values(by='Attack',ascending=False)
# Out:
#       Type 1  Attack
# 17     Water    8305
# 12    Normal    7200
# 9      Grass    5125
# 0        Bug    4897
# 6       Fire    4408
# 15      Rock    4086
# 14   Psychic    4073
# 2     Dragon    3588
# 10    Ground    3064
# 3   Electric    3040
# 1       Dark    2740
# 5   Fighting    2613
# 16     Steel    2503
# 8      Ghost    2361
# 13    Poison    2091
# 11       Ice    1746
# 4      Fairy    1046
# 7     Flying     315

# %%
df.groupby(['Type 1'])['Attack'].agg(['sum','min','max','count','mean']).sort_values(by='max',ascending=False).head(1)
# Out:
#           sum  min  max  count      mean
# Type 1
# Psychic  4073   20  190     57  71.45614

# %%
df['Name'].nunique()
# Out:
# 800

# %%
df.groupby(['Name'])['Attack'].sum()
# Out:
# Name
# Abomasnow                   92
# AbomasnowMega Abomasnow    132
# Abra                        20
# Absol                      130
# AbsolMega Absol            150
#                           ...
# Zoroark                    105
# Zorua                       65
# Zubat                       45
# Zweilous                    85
# Zygarde50% Forme           100
# Name: Attack, Length: 800, dtype: int64

# %%
df.groupby(['Type 1','Legendary'])['Attack'].sum()
# Out:
# Type 1    Legendary
# Bug       False        4897
# Dark      False        2519
#           True          221
# Dragon    False        2068
#           True         1520
# Electric  False        2645
#           True          395
# Fairy     False         915
#           True          131
# Fighting  False        2613
# Fire      False        3863
#           True          545
# Flying    False         100
#           True          215
# Ghost     False        2141
#           True          220
# Grass     False        4832
#           True          293
# Ground    False        2464
#           True          600
# Ice       False        1611
#           True          135
# Normal    False        6920
#           True          280
# Poison    False        2091
# Psychic   False        2363
#           True         1710
# Rock      False        3597
#           True          489
# Steel     False        2118
#           True          385
# Water     False        7860
# ...

# %%
df.to_csv('Updated_pokemon.csv',index=False)

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\cipl\\Pandas'

# %%
df[df['Type 1']=='Grass']
# Out:
#                       Name Type 1   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0                Bulbasaur  Grass   45      49       49       65       65
# 1                  Ivysaur  Grass   60      62       63       80       80
# 2                 Venusaur  Grass   80      82       83      100      100
# 3    VenusaurMega Venusaur  Grass   80     100      123      122      120
# 48                  Oddish  Grass   45      50       55       75       65
# ..                     ...    ...  ...     ...      ...      ...      ...
# 718                Chespin  Grass   56      61       65       48       45
# 719              Quilladin  Grass   61      78       95       56       58
# 720             Chesnaught  Grass   88     107      122       74       75
# 740                 Skiddo  Grass   66      65       48       62       57
# 741                 Gogoat  Grass  123     100       62       97       81
#
#      Speed  Generation  Legendary  total
# ...

# %%
df[df['Attack']>=180]
# Out:
#                         Name   Type 1   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 163      MewtwoMega Mewtwo X  Psychic  106     190      100      154      100
# 232  HeracrossMega Heracross      Bug   80     185      115       40      105
# 424    GroudonPrimal Groudon   Ground  100     180      160      150       90
# 426    RayquazaMega Rayquaza   Dragon  105     180      100      180      100
# 429       DeoxysAttack Forme  Psychic   50     180       20      180       20
#
#      Speed  Generation  Legendary  total
# 163    130           1       True    780
# 232     75           2      False    600
# 424     90           3       True    770
# 426    115           3       True    780
# 429    150           3       True    600

# %%
df[(df['Type 1']=='Grass') & (df['Attack']>120)]
# Out:
#                         Name Type 1  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 310                  Breloom  Grass  60     130       80       60       60
# 511  AbomasnowMega Abomasnow  Grass  90     132      105      132      105
#
#      Speed  Generation  Legendary  total
# 310     70           3      False    460
# 511     30           4      False    594

# %%
col=list(df.columns)
col
# Out:
# ['Name',
#  'Type 1',
#  'HP',
#  'Attack',
#  'Defense',
#  'Sp. Atk',
#  'Sp. Def',
#  'Speed',
#  'Generation',
#  'Legendary',
#  'Total']

# %%
df[col[0:2]+[col[-1]]+col[2:10]]
# Out:
#                       Name   Type 1  Total  HP  Attack  Defense  Sp. Atk  \
# 0                Bulbasaur    Grass    318  45      49       49       65
# 1                  Ivysaur    Grass    405  60      62       63       80
# 2                 Venusaur    Grass    525  80      82       83      100
# 3    VenusaurMega Venusaur    Grass    625  80     100      123      122
# 4               Charmander     Fire    309  39      52       43       60
# ..                     ...      ...    ...  ..     ...      ...      ...
# 795                Diancie     Rock    600  50     100      150      100
# 796    DiancieMega Diancie     Rock    700  50     160      110      160
# 797    HoopaHoopa Confined  Psychic    600  80     110       60      150
# 798     HoopaHoopa Unbound  Psychic    680  80     160       60      170
# 799              Volcanion     Fire    600  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 0         65     45           1      False
# ...

# %%
col=list(df.columns)
col
# Out:
# ['Name',
#  'Type 1',
#  'HP',
#  'Attack',
#  'Defense',
#  'Sp. Atk',
#  'Sp. Def',
#  'Speed',
#  'Generation',
#  'Legendary',
#  'Total']

# %%
# Arranging the columns

df=df[col[0:2]+[col[-1]]+col[2:10]]
df
# Out:
#                       Name   Type 1  Total  HP  Attack  Defense  Sp. Atk  \
# 0                bulbasaur    grass    318  45      49       49       65
# 1                  ivysaur    grass    405  60      62       63       80
# 2                 venusaur    grass    525  80      82       83      100
# 3    venusaurmega venusaur    grass    625  80     100      123      122
# 4               charmander     fire    309  39      52       43       60
# ..                     ...      ...    ...  ..     ...      ...      ...
# 795                diancie     rock    600  50     100      150      100
# 796    dianciemega diancie     rock    700  50     160      110      160
# 797    hoopahoopa confined  psychic    600  80     110       60      150
# 798     hoopahoopa unbound  psychic    680  80     160       60      170
# 799              volcanion     fire    600  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 0         65     45           1      False
# ...

# %%
m=np.array([[55,23,70,90,10,30,100]])
p=60

# %%
m>p
# Out:
# array([[False, False,  True,  True, False, False,  True]])

# %%
m[m>p]
# Out:
# array([ 70,  90, 100])

# %%
df
# Out:
#                       Name   Type 1  Total  HP  Attack  Defense  Sp. Atk  \
# 0                bulbasaur    grass    318  45      49       49       65
# 1                  ivysaur    grass    405  60      62       63       80
# 2                 venusaur    grass    525  80      82       83      100
# 3    venusaurmega venusaur    grass    625  80     100      123      122
# 4               charmander     fire    309  39      52       43       60
# ..                     ...      ...    ...  ..     ...      ...      ...
# 795                diancie     rock    600  50     100      150      100
# 796    dianciemega diancie     rock    700  50     160      110      160
# 797    hoopahoopa confined  psychic    600  80     110       60      150
# 798     hoopahoopa unbound  psychic    680  80     160       60      170
# 799              volcanion     fire    600  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 0         65     45           1      False
# ...

# %%
df['Type 1']=='flying'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 795    False
# 796    False
# 797    False
# 798    False
# 799    False
# Name: Type 1, Length: 800, dtype: bool

# %%
df[df['Type 1']=='flying']
# Out:
#                         Name  Type 1  Total  HP  Attack  Defense  Sp. Atk  \
# 702  tornadusincarnate forme  flying    580  79     115       70      125
# 703    tornadustherian forme  flying    580  79     100       80      110
# 790                   noibat  flying    245  40      30       35       45
# 791                  noivern  flying    535  85      70       80       97
#
#      Sp. Def  Speed  Generation  Legendary
# 702       80    111           5       True
# 703       90    121           5       True
# 790       40     55           6      False
# 791       80    123           6      False

# %%
df[df['Attack']>180]
# Out:
#                         Name   Type 1  Total   HP  Attack  Defense  Sp. Atk  \
# 163      mewtwomega mewtwo x  psychic    780  106     190      100      154
# 232  heracrossmega heracross      bug    600   80     185      115       40
#
#      Sp. Def  Speed  Generation  Legendary
# 163      100    130           1       True
# 232      105     75           2      False

# %%
df[(df['Type 1']=='flying') & (df['Attack']<100)]
# Out:
#         Name  Type 1  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 790   noibat  flying    245  40      30       35       45       40     55
# 791  noivern  flying    535  85      70       80       97       80    123
#
#      Generation  Legendary
# 790           6      False
# 791           6      False

# %%
df[(df['Type 1']=='Fairy') | (df['Legendary']==True)]
# Out:
#                     Name    Type 1  total  HP  Attack  Defense  Sp. Atk  \
# 40              Clefairy     Fairy    323  70      45       48       60
# 41              Clefable     Fairy    483  95      70       73       95
# 156             Articuno       Ice    580  90      85      100       95
# 157               Zapdos  Electric    580  90      90       85      125
# 158              Moltres      Fire    580  90     100       90      125
# ..                   ...       ...    ...  ..     ...      ...      ...
# 795              Diancie      Rock    600  50     100      150      100
# 796  DiancieMega Diancie      Rock    700  50     160      110      160
# 797  HoopaHoopa Confined   Psychic    600  80     110       60      150
# 798   HoopaHoopa Unbound   Psychic    680  80     160       60      170
# 799            Volcanion      Fire    600  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 40        65     35           1      False
# ...

# %%
df[(df['Type 1']=='Fairy') | (df['Type 1']=='Flying')]
# Out:
#                         Name  Type 1   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 40                  Clefairy   Fairy   70      45       48       60       65
# 41                  Clefable   Fairy   95      70       73       95       90
# 187                   Cleffa   Fairy   50      25       28       45       55
# 189                   Togepi   Fairy   35      20       65       40       65
# 190                  Togetic   Fairy   55      40       85       80      105
# 225                 Snubbull   Fairy   60      80       50       40       40
# 226                 Granbull   Fairy   90     120       75       60       60
# 519                 Togekiss   Fairy   85      50       95      120      115
# 702  TornadusIncarnate Forme  Flying   79     115       70      125       80
# 703    TornadusTherian Forme  Flying   79     100       80      110       90
# 737                  Flabébé   Fairy   44      38       39       61       79
# ...

# %%
df[~(df["Legendary"]==True)]
# Out:
#                       Name  Type 1  total  HP  Attack  Defense  Sp. Atk  \
# 0                Bulbasaur   Grass    318  45      49       49       65
# 1                  Ivysaur   Grass    405  60      62       63       80
# 2                 Venusaur   Grass    525  80      82       83      100
# 3    VenusaurMega Venusaur   Grass    625  80     100      123      122
# 4               Charmander    Fire    309  39      52       43       60
# ..                     ...     ...    ...  ..     ...      ...      ...
# 787    GourgeistSuper Size   Ghost    494  85     100      122       58
# 788               Bergmite     Ice    304  55      69       85       32
# 789                Avalugg     Ice    514  95     117      184       44
# 790                 Noibat  Flying    245  40      30       35       45
# 791                Noivern  Flying    535  85      70       80       97
#
#      Sp. Def  Speed  Generation  Legendary
# 0         65     45           1      False
# ...

# %%
df[df["Legendary"]!=True]
# Out:
#                       Name  Type 1  Total  HP  Attack  Defense  Sp. Atk  \
# 0                bulbasaur   grass    318  45      49       49       65
# 1                  ivysaur   grass    405  60      62       63       80
# 2                 venusaur   grass    525  80      82       83      100
# 3    venusaurmega venusaur   grass    625  80     100      123      122
# 4               charmander    fire    309  39      52       43       60
# ..                     ...     ...    ...  ..     ...      ...      ...
# 787    gourgeistsuper size   ghost    494  85     100      122       58
# 788               bergmite     ice    304  55      69       85       32
# 789                avalugg     ice    514  95     117      184       44
# 790                 noibat  flying    245  40      30       35       45
# 791                noivern  flying    535  85      70       80       97
#
#      Sp. Def  Speed  Generation  Legendary
# 0         65     45           1      False
# ...

# %%
df[~(df["Legendary"]==True)]
# Out:
#                       Name  Type 1  Total  HP  Attack  Defense  Sp. Atk  \
# 0                bulbasaur   grass    318  45      49       49       65
# 1                  ivysaur   grass    405  60      62       63       80
# 2                 venusaur   grass    525  80      82       83      100
# 3    venusaurmega venusaur   grass    625  80     100      123      122
# 4               charmander    fire    309  39      52       43       60
# ..                     ...     ...    ...  ..     ...      ...      ...
# 787    gourgeistsuper size   ghost    494  85     100      122       58
# 788               bergmite     ice    304  55      69       85       32
# 789                avalugg     ice    514  95     117      184       44
# 790                 noibat  flying    245  40      30       35       45
# 791                noivern  flying    535  85      70       80       97
#
#      Sp. Def  Speed  Generation  Legendary
# 0         65     45           1      False
# ...

# %%
df.groupby(['Type 1'])['Attack'].sum().sort_values(ascending=False).reset_index()
# Out:
#       Type 1  Attack
# 0      Water    8305
# 1     Normal    7200
# 2      Grass    5125
# 3        Bug    4897
# 4       Fire    4408
# 5       Rock    4086
# 6    Psychic    4073
# 7     Dragon    3588
# 8     Ground    3064
# 9   Electric    3040
# 10      Dark    2740
# 11  Fighting    2613
# 12     Steel    2503
# 13     Ghost    2361
# 14    Poison    2091
# 15       Ice    1746
# 16     Fairy    1046
# 17    Flying     315

# %%
df.groupby(['Type 1'])['Attack'].min().reset_index().sort_values(by='Attack',ascending=False)
# Out:
#       Type 1  Attack
# 2     Dragon      50
# 1       Dark      50
# 13    Poison      43
# 15      Rock      40
# 10    Ground      40
# 5   Fighting      35
# 3   Electric      30
# 6       Fire      30
# 7     Flying      30
# 8      Ghost      30
# 11       Ice      30
# 9      Grass      27
# 16     Steel      24
# 4      Fairy      20
# 14   Psychic      20
# 0        Bug      10
# 17     Water      10
# 12    Normal       5

# %%
df.groupby(['Type 1'])['Attack'].agg(['sum','mean','min','max','count'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1-1667384721.py in <cell line: 0>()
# ----> 1 df.groupby(['Type 1'])['Attack'].agg(['sum','mean','min','max','count']),sort_values(by='Attack',ascending=False)
#
# NameError: name 'df' is not defined

# %%
df.groupby(['Type 1', 'Legendary'])['Attack'].sum()
# Out:
# Type 1    Legendary
# Bug       False        4897
# Dark      False        2519
#           True          221
# Dragon    False        2068
#           True         1520
# Electric  False        2645
#           True          395
# Fairy     False         915
#           True          131
# Fighting  False        2613
# Fire      False        3863
#           True          545
# Flying    False         100
#           True          215
# Ghost     False        2141
#           True          220
# Grass     False        4832
#           True          293
# Ground    False        2464
#           True          600
# Ice       False        1611
#           True          135
# Normal    False        6920
#           True          280
# Poison    False        2091
# Psychic   False        2363
#           True         1710
# Rock      False        3597
#           True          489
# Steel     False        2118
#           True          385
# Water     False        7860
# ...

# %%
df.groupby(['Type 1', 'Legendary'])['Attack'].agg(['sum','max'])
# Out:
#                      sum  max
# Type 1   Legendary
# Bug      False      4897  185
# Dark     False      2519  150
#          True        221  131
# Dragon   False      2068  170
#          True       1520  180
# Electric False      2645  123
#          True        395  115
# Fairy    False       915  120
#          True        131  131
# Fighting False      2613  145
# Fire     False      3863  160
#          True        545  130
# Flying   False       100   70
#          True        215  115
# Ghost    False      2141  165
#          True        220  120
# Grass    False      4832  132
#          True        293  103
# Ground   False      2464  140
#          True        600  180
# Ice      False      1611  130
#          True        135   85
# Normal   False      6920  160
#          True        280  160
# Poison   False      2091  106
# Psychic  False      2363  165
#          True       1710  190
# Rock     False      3597  165
#          True        489  160
# ...

# %%
df.to_csv('update_pokemon.csv',index=False)

# %%
df.groupby(['Type 1'])['Attack'].sum().sort_values()
# Out:
# Type 1
# flying       315
# fairy       1046
# ice         1746
# poison      2091
# ghost       2361
# steel       2503
# fighting    2613
# dark        2740
# electric    3040
# ground      3064
# dragon      3588
# psychic     4073
# rock        4086
# fire        4408
# bug         4897
# grass       5125
# normal      7200
# water       8305
# Name: Attack, dtype: int64

# %%
df.groupby(['Type 1'])['Attack'].agg(['sum','mean','max','min','count']).sort_values(by='mean',ascending=False).reset_index()
# Out:
#       Type 1   sum        mean  max  min  count
# 0     dragon  3588  112.125000  180   50     32
# 1   fighting  2613   96.777778  145   35     27
# 2     ground  3064   95.750000  180   40     32
# 3       rock  4086   92.863636  165   40     44
# 4      steel  2503   92.703704  150   24     27
# 5       dark  2740   88.387097  150   50     31
# 6       fire  4408   84.769231  160   30     52
# 7     flying   315   78.750000  115   30      4
# 8     poison  2091   74.678571  106   43     28
# 9      water  8305   74.151786  155   10    112
# 10     ghost  2361   73.781250  165   30     32
# 11    normal  7200   73.469388  160    5     98
# 12     grass  5125   73.214286  132   27     70
# 13       ice  1746   72.750000  130   30     24
# 14   psychic  4073   71.456140  190   20     57
# 15       bug  4897   70.971014  185   10     69
# 16  electric  3040   69.090909  123   30     44
# 17     fairy  1046   61.529412  131   20     17

# %%
df.groupby(['Type 1','Legendary'])['Attack'].sum().reset_index()
# Out:
#       Type 1  Legendary  Attack
# 0        bug      False    4897
# 1       dark      False    2519
# 2       dark       True     221
# 3     dragon      False    2068
# 4     dragon       True    1520
# 5   electric      False    2645
# 6   electric       True     395
# 7      fairy      False     915
# 8      fairy       True     131
# 9   fighting      False    2613
# 10      fire      False    3863
# 11      fire       True     545
# 12    flying      False     100
# 13    flying       True     215
# 14     ghost      False    2141
# 15     ghost       True     220
# 16     grass      False    4832
# 17     grass       True     293
# 18    ground      False    2464
# 19    ground       True     600
# 20       ice      False    1611
# 21       ice       True     135
# 22    normal      False    6920
# 23    normal       True     280
# 24    poison      False    2091
# 25   psychic      False    2363
# 26   psychic       True    1710
# 27      rock      False    3597
# ...

# %%
df.to_csv('UPDATED.csv',index=False)

# %%
df.describe(include='object')
# Out:
#              Name Type 1
# count         800    800
# unique        800     18
# top     bulbasaur  water
# freq            1    112

# %%
df['Type 1'].mode()
# Out:
# 0    water
# Name: Type 1, dtype: object

# %%
df.head()
# Out:
#                     Name Type 1  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0              Bulbasaur  Grass    318  45      49       49       65       65
# 1                Ivysaur  Grass    405  60      62       63       80       80
# 2               Venusaur  Grass    525  80      82       83      100      100
# 3  VenusaurMega Venusaur  Grass    625  80     100      123      122      120
# 4             Charmander   Fire    309  39      52       43       60       50
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False
# 3     80           1      False
# 4     65           1      False

# %%
a=df[df['Type 1']=='Water']
a
# Out:
#                         Name Type 1  Total  HP  Attack  Defense  Sp. Atk  \
# 9                   Squirtle  Water    314  44      48       65       50
# 10                 Wartortle  Water    405  59      63       80       65
# 11                 Blastoise  Water    530  79      83      100       85
# 12   BlastoiseMega Blastoise  Water    630  79     103      120      135
# 59                   Psyduck  Water    320  50      52       48       65
# ..                       ...    ...    ...  ..     ...      ...      ...
# 724                  Froakie  Water    314  41      56       40       62
# 725                Frogadier  Water    405  54      63       52       83
# 726                 Greninja  Water    530  72      95       67      103
# 762                Clauncher  Water    330  50      53       62       58
# 763                Clawitzer  Water    500  71      73       88      120
#
#      Sp. Def  Speed  Generation  Legendary
# 9         64     43           1      False
# ...

# %%
a[a['Attack']>100]
# Out:
#                         Name Type 1  Total   HP  Attack  Defense  Sp. Atk  \
# 12   BlastoiseMega Blastoise  Water    630   79     103      120      135
# 106                   Krabby  Water    325   30     105       90       25
# 107                  Kingler  Water    475   55     130      115       50
# 140                 Gyarados  Water    540   95     125       79       60
# 141    GyaradosMega Gyarados  Water    640   95     155      109       70
# 174               Feraligatr  Water    530   85     105      100       79
# 242                Octillery  Water    480   75     105       75      105
# 282                 Swampert  Water    535  100     110       90       85
# 283    SwampertMega Swampert  Water    635  100     150      110       95
# 348                 Sharpedo  Water    460   70     120       40       95
# 349    SharpedoMega Sharpedo  Water    560   70     140       70      110
# 374                Crawdaunt  Water    468   63     120       85       90
# ...

# %%
df[(df['Type 1']=='Flying') | (df['Legendary']==False)]
# Out:
#                       Name  Type 1  total  HP  Attack  Defense  Sp. Atk  \
# 0                Bulbasaur   Grass    318  45      49       49       65
# 1                  Ivysaur   Grass    405  60      62       63       80
# 2                 Venusaur   Grass    525  80      82       83      100
# 3    VenusaurMega Venusaur   Grass    625  80     100      123      122
# 4               Charmander    Fire    309  39      52       43       60
# ..                     ...     ...    ...  ..     ...      ...      ...
# 787    GourgeistSuper Size   Ghost    494  85     100      122       58
# 788               Bergmite     Ice    304  55      69       85       32
# 789                Avalugg     Ice    514  95     117      184       44
# 790                 Noibat  Flying    245  40      30       35       45
# 791                Noivern  Flying    535  85      70       80       97
#
#      Sp. Def  Speed  Generation  Legendary
# 0         65     45           1      False
# ...

# %%
df[(df['Type 1']=='Grass') | (df['Legendary']==False)]
# Out:
#                       Name  Type 1  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0                Bulbasaur   Grass  45      49       49       65       65
# 1                  Ivysaur   Grass  60      62       63       80       80
# 2                 Venusaur   Grass  80      82       83      100      100
# 3    VenusaurMega Venusaur   Grass  80     100      123      122      120
# 4               Charmander    Fire  39      52       43       60       50
# ..                     ...     ...  ..     ...      ...      ...      ...
# 787    GourgeistSuper Size   Ghost  85     100      122       58       75
# 788               Bergmite     Ice  55      69       85       32       35
# 789                Avalugg     Ice  95     117      184       44       46
# 790                 Noibat  Flying  40      30       35       45       40
# 791                Noivern  Flying  85      70       80       97       80
#
#      Speed  Generation  Legendary  total
# ...

# %%
df[df['Legendary']!=True]
# Out:
#                       Name  Type 1  Total  HP  Attack  Defense  Sp. Atk  \
# 0                Bulbasaur   Grass    318  45      49       49       65
# 1                  Ivysaur   Grass    405  60      62       63       80
# 2                 Venusaur   Grass    525  80      82       83      100
# 3    VenusaurMega Venusaur   Grass    625  80     100      123      122
# 4               Charmander    Fire    309  39      52       43       60
# ..                     ...     ...    ...  ..     ...      ...      ...
# 787    GourgeistSuper Size   Ghost    494  85     100      122       58
# 788               Bergmite     Ice    304  55      69       85       32
# 789                Avalugg     Ice    514  95     117      184       44
# 790                 Noibat  Flying    245  40      30       35       45
# 791                Noivern  Flying    535  85      70       80       97
#
#      Sp. Def  Speed  Generation  Legendary
# 0         65     45           1      False
# ...

# %%
df[~(df['Legendary']==False)]
# Out:
#                     Name    Type 1  total   HP  Attack  Defense  Sp. Atk  \
# 156             Articuno       Ice    580   90      85      100       95
# 157               Zapdos  Electric    580   90      90       85      125
# 158              Moltres      Fire    580   90     100       90      125
# 162               Mewtwo   Psychic    680  106     110       90      154
# 163  MewtwoMega Mewtwo X   Psychic    780  106     190      100      154
# ..                   ...       ...    ...  ...     ...      ...      ...
# 795              Diancie      Rock    600   50     100      150      100
# 796  DiancieMega Diancie      Rock    700   50     160      110      160
# 797  HoopaHoopa Confined   Psychic    600   80     110       60      150
# 798   HoopaHoopa Unbound   Psychic    680   80     160       60      170
# 799            Volcanion      Fire    600   80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 156      125     85           1       True
# ...

# %%
df[(df['Type 1']=='Water') & (df['Attack']>110) &(df['Speed']>90)]
# Out:
#                       Name Type 1  total  HP  Attack  Defense  Sp. Atk  \
# 348               Sharpedo  Water    460  70     120       40       95
# 349  SharpedoMega Sharpedo  Water    560  70     140       70      110
# 541                 Palkia  Water    680  90     120      100      150
#
#      Sp. Def  Speed  Generation  Legendary
# 348       40     95           3      False
# 349       65    105           3      False
# 541      120    100           4       True

# %%
df[~(df['Legendary']==True)]
# Out:
#                       Name  Type 1  Total  HP  Attack  Defense  Sp. Atk  \
# 0                Bulbasaur   Grass    318  45      49       49       65
# 1                  Ivysaur   Grass    405  60      62       63       80
# 2                 Venusaur   Grass    525  80      82       83      100
# 3    VenusaurMega Venusaur   Grass    625  80     100      123      122
# 4               Charmander    Fire    309  39      52       43       60
# ..                     ...     ...    ...  ..     ...      ...      ...
# 787    GourgeistSuper Size   Ghost    494  85     100      122       58
# 788               Bergmite     Ice    304  55      69       85       32
# 789                Avalugg     Ice    514  95     117      184       44
# 790                 Noibat  Flying    245  40      30       35       45
# 791                Noivern  Flying    535  85      70       80       97
#
#      Sp. Def  Speed  Generation  Legendary
# 0         65     45           1      False
# ...

# %%
df
# Out:
#                       Name   Type 1  Total  HP  Attack  Defense  Sp. Atk  \
# 0                Bulbasaur    Grass    318  45      49       49       65
# 1                  Ivysaur    Grass    405  60      62       63       80
# 2                 Venusaur    Grass    525  80      82       83      100
# 3    VenusaurMega Venusaur    Grass    625  80     100      123      122
# 4               Charmander     Fire    309  39      52       43       60
# ..                     ...      ...    ...  ..     ...      ...      ...
# 795                Diancie     Rock    600  50     100      150      100
# 796    DiancieMega Diancie     Rock    700  50     160      110      160
# 797    HoopaHoopa Confined  Psychic    600  80     110       60      150
# 798     HoopaHoopa Unbound  Psychic    680  80     160       60      170
# 799              Volcanion     Fire    600  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 0         65     45           1      False
# ...

# %%
a=np.array([[30,80,45,95,10,22,70]])
p=60

# %%
a>p
# Out:
# array([[False,  True, False,  True, False, False,  True]])

# %%
a[a>p]
# Out:
# array([80, 95, 70])

# %%
df['Type 1']=='Flying'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 795    False
# 796    False
# 797    False
# 798    False
# 799    False
# Name: Type 1, Length: 800, dtype: bool

# %%
df[df['Type 1']=='Flying']
# Out:
#                         Name  Type 1  Total  HP  Attack  Defense  Sp. Atk  \
# 702  TornadusIncarnate Forme  Flying    580  79     115       70      125
# 703    TornadusTherian Forme  Flying    580  79     100       80      110
# 790                   Noibat  Flying    245  40      30       35       45
# 791                  Noivern  Flying    535  85      70       80       97
#
#      Sp. Def  Speed  Generation  Legendary
# 702       80    111           5       True
# 703       90    121           5       True
# 790       40     55           6      False
# 791       80    123           6      False

# %%
df[(df['Type 1']=='Fire') & (df['Attack']>100)]
# Out:
#                           Name Type 1  Total   HP  Attack  Defense  Sp. Atk  \
# 7    CharizardMega Charizard X   Fire    634   78     130      111      130
# 8    CharizardMega Charizard Y   Fire    634   78     104       78      159
# 64                    Arcanine   Fire    555   90     110       80      100
# 147                    Flareon   Fire    525   65     130       60       95
# 263                      Entei   Fire    580  115     115       85       90
# 270                      Ho-oh   Fire    680  106     130       90      110
# 278                   Blaziken   Fire    530   80     120       70      110
# 279      BlazikenMega Blaziken   Fire    630   80     160       80      130
# 354      CameruptMega Camerupt   Fire    560   70     120      100      145
# 437                  Infernape   Fire    534   76     104       71      104
# 559                     Emboar   Fire    528  110     123       65      100
# ...

# %%
df[(df['Type 1']=='Flying') | (df['Type 1']=='Fairy')]
# Out:
#                         Name  Type 1  Total   HP  Attack  Defense  Sp. Atk  \
# 40                  Clefairy   Fairy    323   70      45       48       60
# 41                  Clefable   Fairy    483   95      70       73       95
# 187                   Cleffa   Fairy    218   50      25       28       45
# 189                   Togepi   Fairy    245   35      20       65       40
# 190                  Togetic   Fairy    405   55      40       85       80
# 225                 Snubbull   Fairy    300   60      80       50       40
# 226                 Granbull   Fairy    450   90     120       75       60
# 519                 Togekiss   Fairy    545   85      50       95      120
# 702  TornadusIncarnate Forme  Flying    580   79     115       70      125
# 703    TornadusTherian Forme  Flying    580   79     100       80      110
# 737                  Flabébé   Fairy    303   44      38       39       61
# ...

# %%
df[(df['Type 1']=='Water') |(df['Legendary']=='False')]
# Out:
#                         Name Type 1  Total  HP  Attack  Defense  Sp. Atk  \
# 9                   Squirtle  Water    314  44      48       65       50
# 10                 Wartortle  Water    405  59      63       80       65
# 11                 Blastoise  Water    530  79      83      100       85
# 12   BlastoiseMega Blastoise  Water    630  79     103      120      135
# 59                   Psyduck  Water    320  50      52       48       65
# ..                       ...    ...    ...  ..     ...      ...      ...
# 724                  Froakie  Water    314  41      56       40       62
# 725                Frogadier  Water    405  54      63       52       83
# 726                 Greninja  Water    530  72      95       67      103
# 762                Clauncher  Water    330  50      53       62       58
# 763                Clawitzer  Water    500  71      73       88      120
#
#      Sp. Def  Speed  Generation  Legendary
# 9         64     43           1      False
# ...

# %%
df.groupby(['Type 1'])['Attack'].max().sort_values(ascending=False)
# Out:
# Type 1
# Psychic     190
# Bug         185
# Dragon      180
# Ground      180
# Ghost       165
# Rock        165
# Normal      160
# Fire        160
# Water       155
# Dark        150
# Steel       150
# Fighting    145
# Grass       132
# Fairy       131
# Ice         130
# Electric    123
# Flying      115
# Poison      106
# Name: Attack, dtype: int64

# %%
df.groupby(['Type 1'])['Attack'].sum().reset_index().sort_values(by='Attack',ascending=False)
# Out:
#       Type 1  Attack
# 17     Water    8305
# 12    Normal    7200
# 9      Grass    5125
# 0        Bug    4897
# 6       Fire    4408
# 15      Rock    4086
# 14   Psychic    4073
# 2     Dragon    3588
# 10    Ground    3064
# 3   Electric    3040
# 1       Dark    2740
# 5   Fighting    2613
# 16     Steel    2503
# 8      Ghost    2361
# 13    Poison    2091
# 11       Ice    1746
# 4      Fairy    1046
# 7     Flying     315

# %%
df.groupby(['Type 1'])['Attack'].agg(['sum','min','max','mean','count']).sort_values(by='max',ascending=False)
# Out:
#            sum  min  max        mean  count
# Type 1
# Psychic   4073   20  190   71.456140     57
# Bug       4897   10  185   70.971014     69
# Dragon    3588   50  180  112.125000     32
# Ground    3064   40  180   95.750000     32
# Ghost     2361   30  165   73.781250     32
# Rock      4086   40  165   92.863636     44
# Normal    7200    5  160   73.469388     98
# Fire      4408   30  160   84.769231     52
# Water     8305   10  155   74.151786    112
# Dark      2740   50  150   88.387097     31
# Steel     2503   24  150   92.703704     27
# Fighting  2613   35  145   96.777778     27
# Grass     5125   27  132   73.214286     70
# Fairy     1046   20  131   61.529412     17
# Ice       1746   30  130   72.750000     24
# Electric  3040   30  123   69.090909     44
# Flying     315   30  115   78.750000      4
# Poison    2091   43  106   74.678571     28

# %%
df
# Out:
#                       Name   Type 1  total  HP  Attack  Defense  Sp. Atk  \
# 0                Bulbasaur    Grass    318  45      49       49       65
# 1                  Ivysaur    Grass    405  60      62       63       80
# 2                 Venusaur    Grass    525  80      82       83      100
# 3    VenusaurMega Venusaur    Grass    625  80     100      123      122
# 4               Charmander     Fire    309  39      52       43       60
# ..                     ...      ...    ...  ..     ...      ...      ...
# 795                Diancie     Rock    600  50     100      150      100
# 796    DiancieMega Diancie     Rock    700  50     160      110      160
# 797    HoopaHoopa Confined  Psychic    600  80     110       60      150
# 798     HoopaHoopa Unbound  Psychic    680  80     160       60      170
# 799              Volcanion     Fire    600  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 0         65     45           1      False
# ...

# %%
df
# Out:
#                       Name   Type 1  total  HP  Attack  Defense  Sp. Atk  \
# 0                Bulbasaur    Grass    318  45      49       49       65
# 1                  Ivysaur    Grass    405  60      62       63       80
# 2                 Venusaur    Grass    525  80      82       83      100
# 3    VenusaurMega Venusaur    Grass    625  80     100      123      122
# 4               Charmander     Fire    309  39      52       43       60
# ..                     ...      ...    ...  ..     ...      ...      ...
# 795                Diancie     Rock    600  50     100      150      100
# 796    DiancieMega Diancie     Rock    700  50     160      110      160
# 797    HoopaHoopa Confined  Psychic    600  80     110       60      150
# 798     HoopaHoopa Unbound  Psychic    680  80     160       60      170
# 799              Volcanion     Fire    600  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 0         65     45           1      False
# ...

# %%
df.drop(columns=['total'],inplace=True)
# Out:
# C:\Users\cipl\AppData\Local\Temp\ipykernel_2792\1757500260.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['total'],inplace=True)

# %%
df.to_excel('abcd.xlsx')

# %%
df
# Out:
#                       Name   Type 1  total  HP  Attack  Defense  Sp. Atk  \
# 0                Bulbasaur    Grass   1182  45      49       49       65
# 1                  Ivysaur    Grass   1500  60      62       63       80
# 2                 Venusaur    Grass   1940  80      82       83      100
# 3    VenusaurMega Venusaur    Grass   2340  80     100      123      122
# 4               Charmander     Fire   1106  39      52       43       60
# ..                     ...      ...    ...  ..     ...      ...      ...
# 795                Diancie     Rock   2300  50     100      150      100
# 796    DiancieMega Diancie     Rock   2580  50     160      110      160
# 797    HoopaHoopa Confined  Psychic   2260  80     110       60      150
# 798     HoopaHoopa Unbound  Psychic   2560  80     160       60      170
# 799              Volcanion     Fire   2260  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary  Total
# ...

# %%
df.to_csv('weekday4.csv',index=False)

# %% [markdown]
# ## Saving our Data (Exporting into desired format)

# %% [markdown]
# ## To save the dataset

# %%
# pokemon.to_csv('updated_pokemon.csv',index=False) #here index=False to delete the extra indexes of csv format
df.to_csv('updated_pokemon.csv',index=False) #here index=False to delete the extra indexes of csv format

# %%
# pokemon

# %%
df
# Out:
#                       Name   Type 1  total  HP  Attack  Defense  Sp. Atk  \
# 0                Bulbasaur    Grass   1182  45      49       49       65
# 1                  Ivysaur    Grass   1500  60      62       63       80
# 2                 Venusaur    Grass   1940  80      82       83      100
# 3    VenusaurMega Venusaur    Grass   2340  80     100      123      122
# 4               Charmander     Fire   1106  39      52       43       60
# ..                     ...      ...    ...  ..     ...      ...      ...
# 795                Diancie     Rock   2300  50     100      150      100
# 796    DiancieMega Diancie     Rock   2580  50     160      110      160
# 797    HoopaHoopa Confined  Psychic   2260  80     110       60      150
# 798     HoopaHoopa Unbound  Psychic   2560  80     160       60      170
# 799              Volcanion     Fire   2260  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary  Total
# ...

# %%
df[df['Attack']>160]
# Out:
#                         Name   Type 1  Total   HP  Attack  Defense  Sp. Atk  \
# 163      MewtwoMega Mewtwo X  Psychic    780  106     190      100      154
# 232  HeracrossMega Heracross      Bug    600   80     185      115       40
# 268  TyranitarMega Tyranitar     Rock    700  100     164      150       95
# 387      BanetteMega Banette    Ghost    555   64     165       75       93
# 424    GroudonPrimal Groudon   Ground    770  100     180      160      150
# 426    RayquazaMega Rayquaza   Dragon    780  105     180      100      180
# 429       DeoxysAttack Forme  Psychic    600   50     180       20      180
# 454                Rampardos     Rock    495   97     165       60       65
# 494    GarchompMega Garchomp   Dragon    700  108     170      115      120
# 527      GalladeMega Gallade  Psychic    618   68     165       95       65
# 711       KyuremBlack Kyurem   Dragon    700  125     170      100      120
#
#      Sp. Def  Speed  Generation  Legendary
# ...

# %%
df[(df['Type 1']=='Rock') | (df['Attack']>160)]
# Out:
#                           Name   Type 1  Total   HP  Attack  Defense  Sp. Atk  \
# 80                     Geodude     Rock    300   40      80      100       30
# 81                    Graveler     Rock    390   55      95      115       45
# 82                       Golem     Rock    495   80     120      130       55
# 103                       Onix     Rock    385   35      45      160       30
# 149                    Omanyte     Rock    355   35      40      100       90
# 150                    Omastar     Rock    495   70      60      125      115
# 151                     Kabuto     Rock    355   30      80       90       55
# 152                   Kabutops     Rock    495   60     115      105       65
# 153                 Aerodactyl     Rock    515   80     105       65       60
# 154  AerodactylMega Aerodactyl     Rock    615   80     135       85       70
# 163        MewtwoMega Mewtwo X  Psychic    780  106     190      100      154
# ...

# %% [markdown]
# ## Filtering of data Or Condition in data

# %%
pd.set_option('display.max_rows',None)

# %%
df[(df['Type 1']=="Grass") | (df['Legendary']==True)]
# Out:
#                          Name    Type 1  Total   HP  Attack  Defense  Sp. Atk  \
# 0                   Bulbasaur     Grass    318   45      49       49       65
# 1                     Ivysaur     Grass    405   60      62       63       80
# 2                    Venusaur     Grass    525   80      82       83      100
# 3       VenusaurMega Venusaur     Grass    625   80     100      123      122
# 48                     Oddish     Grass    320   45      50       55       75
# 49                      Gloom     Grass    395   60      65       70       85
# 50                  Vileplume     Grass    490   75      80       85      110
# 75                 Bellsprout     Grass    300   50      75       35       70
# 76                 Weepinbell     Grass    390   65      90       50       85
# 77                 Victreebel     Grass    490   80     105       65      100
# 110                 Exeggcute     Grass    325   60      40       80       60
# ...

# %%
#df.groupby('Lagendary')

# %%
# df[(df['Type 1']=="Dragon") & (df['Type 2']=='Fire')]

# %%
df[(df['Type 1']=="Grass") | (df['Legendary']==True)]
# Out:
#                       Name   Type 1  total  HP  Attack  Defense  Sp. Atk  \
# 0                Bulbasaur    Grass   1182  45      49       49       65
# 1                  Ivysaur    Grass   1500  60      62       63       80
# 2                 Venusaur    Grass   1940  80      82       83      100
# 3    VenusaurMega Venusaur    Grass   2340  80     100      123      122
# 48                  Oddish    Grass   1220  45      50       55       75
# ..                     ...      ...    ...  ..     ...      ...      ...
# 795                Diancie     Rock   2300  50     100      150      100
# 796    DiancieMega Diancie     Rock   2580  50     160      110      160
# 797    HoopaHoopa Confined  Psychic   2260  80     110       60      150
# 798     HoopaHoopa Unbound  Psychic   2560  80     160       60      170
# 799              Volcanion     Fire   2260  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary  Total
# ...

# %%
df[df['Type 1']!='Water']
# Out:
#                       Name   Type 1  total  HP  Attack  Defense  Sp. Atk  \
# 0                Bulbasaur    Grass   1182  45      49       49       65
# 1                  Ivysaur    Grass   1500  60      62       63       80
# 2                 Venusaur    Grass   1940  80      82       83      100
# 3    VenusaurMega Venusaur    Grass   2340  80     100      123      122
# 4               Charmander     Fire   1106  39      52       43       60
# ..                     ...      ...    ...  ..     ...      ...      ...
# 795                Diancie     Rock   2300  50     100      150      100
# 796    DiancieMega Diancie     Rock   2580  50     160      110      160
# 797    HoopaHoopa Confined  Psychic   2260  80     110       60      150
# 798     HoopaHoopa Unbound  Psychic   2560  80     160       60      170
# 799              Volcanion     Fire   2260  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary  Total
# ...

# %%
df[~(df['Legendary']==True)]
# Out:
#                       Name  Type 1  total  HP  Attack  Defense  Sp. Atk  \
# 0                Bulbasaur   Grass   1182  45      49       49       65
# 1                  Ivysaur   Grass   1500  60      62       63       80
# 2                 Venusaur   Grass   1940  80      82       83      100
# 3    VenusaurMega Venusaur   Grass   2340  80     100      123      122
# 4               Charmander    Fire   1106  39      52       43       60
# ..                     ...     ...    ...  ..     ...      ...      ...
# 787    GourgeistSuper Size   Ghost   1868  85     100      122       58
# 788               Bergmite     Ice   1160  55      69       85       32
# 789                Avalugg     Ice   2000  95     117      184       44
# 790                 Noibat  Flying    870  40      30       35       45
# 791                Noivern  Flying   1894  85      70       80       97
#
#      Sp. Def  Speed  Generation  Legendary  Total
# 0         65     45           1      False   1455
# ...

# %%
df[df['Name']=='Pikachu']#To find the any name in the data
# Out:
#        Name    Type 1  total  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 30  Pikachu  Electric   1100  35      55       40       50       50     90
#
#     Generation  Legendary  Total
# 30           1      False   1330

# %%
legendary_counts = df.groupby(['Type 1', 'Legendary']).size().unstack(fill_value=0)
print(legendary_counts)
# Out:
# Legendary  False  True
# Type 1
# Bug           69      0
# Dark          29      2
# Dragon        20     12
# Electric      40      4
# Fairy         16      1
# Fighting      27      0
# Fire          47      5
# Flying         2      2
# Ghost         30      2
# Grass         67      3
# Ground        28      4
# Ice           22      2
# Normal        96      2
# Poison        28      0
# Psychic       43     14
# Rock          40      4
# Steel         23      4
# Water        108      4
